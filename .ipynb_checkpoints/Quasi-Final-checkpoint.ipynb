# %%
# pip install jyquickhelper

# %% [markdown]
# # Sommaire

# %%
from jyquickhelper import add_notebook_menu
add_notebook_menu()
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
#         var child = null;
#         for(t = 0; t < tags.length; t++) {
#             var r = anchors[i].getElementsByTagName(tags[t]);
#             if (r.length > 0) {
# child = r[0];
# break;
#             }
#         }
#         if (child == null) {
#             text_memo += "null\n";
#             continue;
#         }
#         if (anchors[i].hasAttribute("id")) {
#             // when converted in RST
#             href = anchors[i].id;
#             text_memo += "#1-" + href;
#             // passer à child suivant (le chercher)
#         }
#         else if (child.hasAttribute("id")) {
#             // in a notebook
#             href = child.id;
#             text_memo += "#2-" + href;
#         }
#         else {
#             text_memo += "#3-" + "*" + "\n";
#             continue;
#         }
#         var title = child.textContent;
#         var level = parseInt(child.tagName.substring(1,2));
#
#         text_memo += "--" + level + "?" + lfirst + "--" + title + "\n";
#
#         if ((level < lfirst) || (level > llast)) {
#             continue ;
#         }
#         if (title.endsWith('¶')) {
#             title = title.substring(0,title.length-1).replace("<", "&lt;")
#          .replace(">", "&gt;").replace("&", "&amp;");
#         }
#         if (title.length == 0) {
#             continue;
#         }
#
#         while (level < memo_level) {
#             text_menu += end_format + "</ul>\n";
#             format_open -= 1;
#             memo_level -= 1;
#         }
#         if (level == lfirst) {
#             main_item += 1;
#         }
#         if (keep_item != -1 && main_item != keep_item + 1) {
#             // alert(main_item + " - " + level + " - " + keep_item);
#             continue;
#         }
#         while (level > memo_level) {
#             text_menu += "<ul>\n";
#             memo_level += 1;
#         }
#         text_menu += repeat_indent_string(level-2);
#         text_menu += begin_format + sformat.replace("__HREF__", href).replace("__TITLE__", title);
#         format_open += 1;
#     }
#     while (1 < memo_level) {
#         text_menu += end_format + "</ul>\n";
#         memo_level -= 1;
#         format_open -= 1;
#     }
#     text_menu += send;
#     //text_menu += "\n" + text_memo;
#
#     while (format_open > 0) {
#         text_menu += end_format;
#         format_open -= 1;
#     }
#     return text_menu;
# };
# var update_menu = function() {
#     var sbegin = "";
#     var sformat = '<a href="#__HREF__">__TITLE__</a>';
#     var send = "";
#     var begin_format = '<li>';
#     var end_format = '</li>';
#     var keep_item = -1;
#     var text_menu = update_menu_string(sbegin, 2, 4, sformat, send, keep_item,
#        begin_format, end_format);
#     var menu = document.getElementById("my_id_menu_nb");
#     menu.innerHTML=text_menu;
# };
# window.setTimeout(update_menu,2000);
#             </script>

# %% [markdown]
# ## Description du projet

# %% [markdown]
# ### Objectifs du projet

# %% [markdown]
# L'objectif initial est de se famliariser avec le monde de la finance et les données financières. Pour cela on se concentre sur les actions boursieres Facebook et Apple, sur lesquelles on essaye de prédire le prix journalier de fermeture, la différence de prix pendant deux jours (le delta) et enfin de prendre des décisions en classifiant ..................
#
# L'objectif principal est de pouvoir prédire le prix journalier d'ouverture ou de fermeture d'une action à partir de données financières des jours antérieurs. Tout en se familiarisant avec le monde de la finance, ce projet est l'occasion pour nous de sonder réellement la plus-value de l'apprentissage automatique pour prédire l'évolution d'un actif financier. Ainsi, il s'agit de comprendre la particularité des séries temporelles traitées pour pouvoir ensuite appliquer le modèle prédictif le plus adéquat. Nous proposons à la toute fin une stratégie simpliste d'achat/vente pour rendre compte de l'intérêt que peuvent apporter de solides prédictions réalisées grâce à l'apprentissage automatique.

# %% [markdown]
# ### Bases de données utiisées

# %% [markdown]
# Dans le cadre de ce projet, nous nous intéressons à la prédiction des actions des GAFAM, et plus particulièrement à Apple. De fait, nous avons exploité toutes les données qui nous paraissaient pertinentes pour cette prédiction, à savoir les données fournies par les cours boursiers des GAFAM, mais aussi les données de l'indicateur de volatilité (VIX) et de l'or (GOLD). Ces deux derniers sont intéressants car la volatilité permet d'expliquer les mouvements brusques des cours et l'or est considéré comme une valeur refuge qui peut possiblement évoluer de manière contraire aux GAFAM lors de crises finanicères.
#
# Pour recueillir les données, nous avons tout d'abord chercher à scraper à la main sur des sites internet. Néanmoins, cette méthode s'avérait peu efficace compte tenu de la multitude d'API déjà existantes. Ainsi, nous avons utilisé les API d'Alphavantage, Tiingo et YahooFinance. Les données présentées ici viennent essentiellement de YahooFinance.

# %% [markdown]
# ### Méthodologie et modèles

# %% [markdown]
# Notre idée consiste à appliquer différentes méthodes de Machine Learning pour sélectionner ensuite la plus performante. Compte tenu de la nature temporelle des données, nous nous attendions à ce que les méthodes de Deep Learning surperforment les méthodes plus classiques d'apprentissage automatique. Néanmoins, il peut être intéressant de tester des méthodes moins élaborées, notamment car ces dernières sont rapides à mettre en place et fournissent un repère pour nos prédictions.
#
# Ainsi, les méthodes utilisées sont :
#
# 1.   Regression Linéaire
# 2.   Gradient Boosting avec des arbres de décision
# 3.   MLP
# 4.   LSTM
# 5.   SVM pour la classification
#
#
# L'intérêt des LSTM par rapport aux autres modèles est de posséder une architecture qui permet de se souvenir plus aisément lors de l'apprentissage de données financières anciennes. Dans ce qui suit, nous montrerons essentiellement l'implémentation de cette méthode. Toutefois, nous avons mis en annexe les codes utilisant les autres méthodes.
#
# Pour éviter une surexploitation des données de la veille seulement pour la prédiction, nous prédirons également le delta(différence entre le prix d'aujourd'hui et de la veille) pour voir si les résultats obtenus sont meilleurs.

# %% [markdown]
# ## Code

# %% [markdown]
# ## Objectif 1 : Prédire le prix close d'Apple

# %% [markdown]
# Dans cette première section nous essayons de prédire le prix de fermeture de l'action Apple.

# %% [markdown]
# ### Import des librairies classiques

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sn
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
import keras

from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Récupération des données

# %% [markdown]
# Il y a dans le jupyter "scrap_data.ipynb" différentes méthodes de scrapping, une à la main et d'autres via des API. Nous avons écrit les avantages de chaque méthode. Ici nous retenons la troisième méthode avec la librairie pandas_datareader.

# %%
import pandas_datareader as web
from sklearn.feature_selection import RFE
import statsmodels.api as sm
import pylab

# %% [markdown]
# ### Définition du dataframe initial

# %% [markdown]
# Dans cette section df_gafa_and_vix correspond au dataframe des prix journaliers de fermeture/ouverture/maximum/minimum de l'actions d'Apple/Amazon/Google/Or et de l'indicateur VIX. Ce dataframe sera enrichi de la moyenne mobile plus tard. Nous selectionnerons (via la méthode RFE) aussi les 8 colonnes les plus importantes pour prédire le prix de fermeture d'Apple .

# %%
start = pd.to_datetime('2012-01-01')
end = pd.to_datetime('today')

df_web_aapl = web.DataReader('AAPL', data_source='yahoo', start=start, end=end)[:2156]
df_web_aapl.columns = ['High_AAPL', 'Low_AAPL', 'Open_AAPL', 'Close_AAPL', 'Volume_AAPL', 'Adj_Close_AAPL']

df_web_amzn = web.DataReader('AMZN', data_source='yahoo', start=start, end=end)[:2156]
df_web_amzn.columns = ['High_AMZN', 'Low_AMZN', 'Open_AMZN', 'Close_AMZN', 'Volume_AMZN', 'Adj_Close_AMZN']

df_web_googl = web.DataReader('GOOGL', data_source='yahoo', start=start, end=end)[:2156]
df_web_googl.columns = ['High_GOOGL', 'Low_GOOGL', 'Open_GOOGL', 'Close_GOOGL', 'Volume_GOOGL', 'Adj_Close_GOOGL']

df_web_vix = web.DataReader('^VIX', data_source='yahoo', start=start, end=end)[:2156]
df_web_vix.columns = ['High_VIX', 'Low_VIX', 'Open_VIX', 'Close_VIX', 'Volume_VIX', 'Adj_Close_VIX']
df_web_vix = df_web_vix[['High_VIX', 'Low_VIX', 'Open_VIX', 'Close_VIX']]

df_web_gold = web.DataReader('GOLD', data_source='yahoo', start=start, end=end)[:2156]
df_web_gold.columns = ['High_GOLD', 'Low_GOLD', 'Open_GOLD', 'Close_GOLD', 'Volume_GOLD', 'Adj_Close_GOLD']



df_gafa_and_vix =pd.concat([df_web_aapl,df_web_amzn,df_web_gold,df_web_vix], axis=1)

# %% [markdown]
# Nous supprimons les données de l'année 2020 car elles correspondent à la periode de coronavirus. Avant de les supprimer, nous avions des modèles qui avaient beaucoup de mal à prédire Ce qui confirme l'aspect difficilement prédictible de cette période, tout du moins en utilisant de l'apprentissage automatique à partir de données boursières seulement. Dans tout ce qui suit, le 1er janvier 2012 sera pris comme origine de la date.

# %%
df_gafa_and_vix = df_gafa_and_vix[:-225]
df_gafa_and_vix = df_gafa_and_vix.reset_index(drop=True)
df_gafa_and_vix.head()
# Out:
#    High_AAPL   Low_AAPL  Open_AAPL  Close_AAPL  Volume_AAPL  Adj_Close_AAPL  \
# 0  14.732142  14.607142  14.621428   14.686786  302220800.0       12.566676
# 1  14.810000  14.617143  14.642858   14.765715  260022000.0       12.634213
# 2  14.948215  14.738214  14.819643   14.929643  271269600.0       12.774481
# 3  15.098214  14.972143  14.991786   15.085714  318292800.0       12.908023
# 4  15.276786  15.048214  15.196428   15.061786  394024400.0       12.887549
#
#     High_AMZN    Low_AMZN   Open_AMZN  Close_AMZN  ...  High_GOLD   Low_GOLD  \
# 0  179.479996  175.550003  175.889999  179.029999  ...  47.770000  46.200001
# 1  180.500000  176.070007  179.210007  177.509995  ...  48.490002  47.330002
# 2  178.250000  174.050003  175.940002  177.610001  ...  48.520000  47.419998
# 3  184.649994  177.500000  178.070007  182.610001  ...  48.299999  47.270000
# 4  184.369995  177.000000  182.759995  178.559998  ...  48.029999  47.250000
#
#    Open_GOLD  Close_GOLD  Volume_GOLD  Adj_Close_GOLD   High_VIX    Low_VIX  \
# 0  46.270000   47.509998    9010200.0       41.618229  23.100000  22.540001
# 1  47.480000   48.220001    8905400.0       42.240177  23.730000  22.219999
# 2  47.720001   48.020000    5800800.0       42.064991  23.090000  21.340000
# 3  48.299999   47.540001    4527100.0       41.644520  21.719999  20.580000
# 4  47.720001   47.709999    3958600.0       41.793423  21.780001  21.000000
#
#     Open_VIX  Close_VIX
# 0  22.950001  22.969999
# 1  23.440001  22.219999
# 2  22.750000  21.480000
# 3  21.240000  20.629999
# 4  21.670000  21.070000
#
# [5 rows x 22 columns]

# %%
len(df_gafa_and_vix)
# Out:
# 1931

# %% [markdown]
# Nous avons concaténé différents dataframes de différents stocks, il faut donc vérifier qu'il n'y a pas d'incompatibilité entre eux, comme par exemple des jours qui seraient fériers pour un stock et pas pour un autre, auquel cas nous aurions des 'NaN'.

# %%
df_gafa_and_vix.isnull().sum()
# Out:
# High_AAPL         0
# Low_AAPL          0
# Open_AAPL         0
# Close_AAPL        0
# Volume_AAPL       0
# Adj_Close_AAPL    0
# High_AMZN         0
# Low_AMZN          0
# Open_AMZN         0
# Close_AMZN        0
# Volume_AMZN       0
# Adj_Close_AMZN    0
# High_GOLD         0
# Low_GOLD          0
# Open_GOLD         0
# Close_GOLD        0
# Volume_GOLD       0
# Adj_Close_GOLD    0
# High_VIX          0
# Low_VIX           0
# Open_VIX          0
# Close_VIX         0
# dtype: int64

# %% [markdown]
# df_gafa_and_vix est donc un gros dataframe avec les prix journaliers (close, open, high, low,adj_close) de certains stocks des GAFAM, de l'or et de l'indicateur VIX (l'indicateur de volatilité du marché).
#
# Nous avons intégré le VIX pour la raison suivante. Avant de supprimer les données de la période du coronavirus, nous avions testé des modèles pour prédire le prix journalier de fermeture (le close) d'Apple et nous avions remarqué que le jeu de test était bien différent du jeu de train. En effet, nous n'avions pas mélangé nos données d'entraînement et de test de manière aléatoire pour garder la temporalité de nos données. En conséquence, le jeu de test correspondait également à la période de coronavirus. Il nous a alors semblé pertinent d'ajouter le VIX pour mieux prédire face à la volatilité du marché.

# %% [markdown]
# # Statistiques descriptives

# %% [markdown]
# Visualisation de la variable à prédire

# %%
plt.figure(figsize=(16,10))
plt.title('Historique des prix de femeture pour Apple', fontsize=20)
df_gafa_and_vix['Close_AAPL'].plot()
plt.xlabel('Date', fontsize=18)
plt.ylabel('Prix de fermeture ($)', fontsize=18)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.title('Boxplot des prix de femeture pour Apple', fontsize=20)
df_gafa_and_vix.boxplot(column = 'Close_AAPL')
plt.ylabel('Prix de fermeture ($)', fontsize=18)
plt.show()

# %% [markdown]
# On peut voir sur ce boxplot que la médiane se trouve juste en dessous de 30 dollars, puis que 75% des valeurs sont inférieures à 40 dollars et qu'il n'y a pas à priori de valeurs extrêmes ou abérrantes. On trouve aussi le max et le min qui valent un peu moins de 60 dollars pour l'un et un peu plus de 10 dollars pour l'autre.

# %%
df_gafa_and_vix["Close_AAPL"].describe()
# Out:
# count    1931.000000
# mean       30.420702
# std        11.178842
# min        13.947500
# 25%        21.162500
# 50%        27.900000
# 75%        39.102501
# max        58.017502
# Name: Close_AAPL, dtype: float64

# %% [markdown]
# Cette méthode describe() permet de confirmer l'analyse du boxplot et nous donne aussi la valeur moyenne (30.4 dollars) et l'écart type (11.2 dollars).

# %% [markdown]
# ### Régression linéaire

# %%
# Reg
#vecteur cible
XTrain = df_gafa_and_vix[['High_AAPL', 'Low_AAPL', 'Open_AAPL', 'Volume_AAPL',
       'Adj_Close_AAPL', 'High_AMZN', 'Low_AMZN', 'Open_AMZN', 'Close_AMZN',
       'Volume_AMZN', 'Adj_Close_AMZN', 'High_GOLD', 'Low_GOLD', 'Open_GOLD',
       'Close_GOLD', 'Volume_GOLD', 'Adj_Close_GOLD', 'High_VIX', 'Low_VIX',
       'Open_VIX', 'Close_VIX']]
yTrain = df_gafa_and_vix[['Close_AAPL']]
#lancer la régression
reg = sm.OLS(yTrain,XTrain)
resReg = reg.fit()

# %%
print(resReg.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             Close_AAPL   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          7.089e+06
# Date:                Tue, 15 Dec 2020   Prob (F-statistic):                        0.00
# Time:                        09:48:53   Log-Likelihood:                          1370.8
# No. Observations:                1931   AIC:                                     -2702.
# Df Residuals:                    1911   BIC:                                     -2590.
# Df Model:                          20
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# High_AAPL          0.5414      0.018     30.697      0.000       0.507       0.576
# Low_AAPL           0.5983      0.016     38.020      0.000       0.567       0.629
# Open_AAPL         -0.3494      0.015    -23.336      0.000      -0.379      -0.320
# Volume_AAPL     1.213e-10   2.52e-11      4.813      0.000    7.19e-11    1.71e-10
# Adj_Close_AAPL     0.2336      0.011     21.835      0.000       0.213       0.255
# High_AMZN         -0.0073      0.001    -11.593      0.000      -0.009      -0.006
# Low_AMZN          -0.0060      0.001    -11.211      0.000      -0.007      -0.005
# Open_AMZN          0.0040      0.001      7.612      0.000       0.003       0.005
# Close_AMZN         0.0044      0.000     16.114      0.000       0.004       0.005
# Volume_AMZN     4.129e-09   1.51e-09      2.726      0.006    1.16e-09     7.1e-09
# Adj_Close_AMZN     0.0044      0.000     16.114      0.000       0.004       0.005
# High_GOLD          0.0111      0.020      0.564      0.573      -0.028       0.050
# Low_GOLD           0.0175      0.019      0.901      0.368      -0.021       0.056
# Open_GOLD         -0.0198      0.017     -1.191      0.234      -0.052       0.013
# Close_GOLD         0.0294      0.019      1.535      0.125      -0.008       0.067
# Volume_GOLD     9.785e-10   4.92e-10      1.988      0.047     1.3e-11    1.94e-09
# Adj_Close_GOLD    -0.0390      0.010     -4.050      0.000      -0.058      -0.020
# High_VIX           0.0273      0.004      6.206      0.000       0.019       0.036
# Low_VIX            0.0441      0.006      7.720      0.000       0.033       0.055
# Open_VIX           0.0032      0.005      0.652      0.515      -0.006       0.013
# Close_VIX         -0.0684      0.005    -13.098      0.000      -0.079      -0.058
# ==============================================================================
# Omnibus:                      238.195   Durbin-Watson:                   1.613
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              935.135
# Skew:                          -0.553   Prob(JB):                    8.67e-204
# Kurtosis:                       6.225   Cond. No.                     1.33e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.03e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Cette regression linéaire nous donne bien que presque chaque variable, toute chose égale par ailleurs, a un coefficient significativement non nul à un seuil de confiance très élevé (superieur à 95 pourcents et superieur à 99.9 pourcents pour celles dont la pvalue vaut 0.000), exception faite pour le high/open/low/close du Gold pour lesquelles nous ne pouvons pas rejeter à un seuil de confiance de plus de 10% l'hypothèse de nullité des coeficients. Nouns ne pouvons pas non plus rejeter l'hypothèse de nullité du coefficient devant Open_VIX.

# %% [markdown]
# Vérifions donc avec un test de Fisher si ces variables peuvent être conjointement non significatives à un certain seuil de confiance :

# %%
#'High_AAPL','Close_AAPL', 'Low_AAPL', 'Open_AAPL', 'Adj_Close_AAPL', 'Close_GOLD', 'Close_VIX'
hypotheses = '(Open_GOLD = 0), (Close_GOLD=0), (Low_GOLD = 0), (High_GOLD=0)'
f_test = resReg.f_test(hypotheses)
print(f_test)
# Out:
# <F test: F=array([[5.23044474]]), p=0.0003439431530167083, df_denom=1.91e+03, df_num=4>

# %% [markdown]
# Grâce à ce test de Fisher, nous pouvons rejeter l'hyothèse de nullité jointe des variables high/open/low/close du Gold au seuil de 99%.

# %% [markdown]
# ### Sélection de variables

# %% [markdown]
# On utilise RFE psq............

# %%
XTrain = df_gafa_and_vix[['High_AAPL', 'Low_AAPL', 'Open_AAPL', 'Volume_AAPL', 'Adj_Close_AAPL','High_AMZN', 'Low_AMZN', 'Open_AMZN', 'Close_AMZN', 'Volume_AMZN','Adj_Close_AMZN','High_GOLD', 'Low_GOLD', 'Open_GOLD', 'Close_GOLD', 'Volume_GOLD', 'Adj_Close_GOLD', 'High_VIX', 'Low_VIX', 'Open_VIX', 'Close_VIX']]
yTrain = df_gafa_and_vix[['Close_AAPL']]

model = LinearRegression()
rfe = RFE(model, 7)
X_rfe = rfe.fit_transform(XTrain,yTrain)  
model.fit(X_rfe,yTrain)
#print(rfe.support_)
print(rfe.ranking_)
#print(XTrain.shape)
# Out:
# [ 1  1  1 15  1  9  6 11  8 14  7  4  5 12  1 13  1  2  3 10  1]
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# #### Résultats de la sélection

# %% [markdown]
# Comme attendu, les informations concernants APPLE sont toutes retenues sauf le volume journalier, mais aussi la valeur de l'indice de volatilité à la fermeture et le cours de l'or à la fermeture.
#
# Nous construisons donc le nouveau dataframe :

# %%
df_train_rfe_et_close = df_gafa_and_vix[['High_AAPL','Close_AAPL', 'Low_AAPL', 'Open_AAPL', 'Adj_Close_AAPL', 'Close_GOLD', 'Close_VIX']]

# %% [markdown]
# #### Moyenne mobile

# %% [markdown]
# La moyenne mobile exponentielle (EMA) est une moyenne mobile pondérée dans le temps. Par cette pondération, elle accorde plus de poids aux prix de clôture les plus récents, et moins aux prix de clôture les plus anciens. L'EMA est très utilisée par les traders car c'est un bon indicateur de tendance. Nous avons choisi de prendre en compte les cinquante derniers jours pour avoir un suivi de tendance assez lisse. L'intérêt de l'incorporer dans nos données est d'éviter un surapprentissage dans des configurations assez volatiles et brusques qui seraient soudaines et contraires à la tendance générale. L'idée derrière est de permettre à l'algorithme de plus facilement garder en mémoire la tendance passée pour prédire le prix du lendemain.

# %%
# Création de la moyenne mobile exponentielle
df_stock = df_train_rfe_et_close['Close_AAPL']
ema = pd.Series.ewm(df_stock, span=50).mean()
dataset_ema = np.reshape(ema.values,(len(ema),1))
ema.values
# Out:
# array([14.6867857 , 14.72703946, 14.79729289, ..., 50.86542512,
#        50.92158494, 51.01564042])

# %%
# Visualisation des prix de fermeture
plt.figure(figsize=(16,8))
plt.title('Historique des prix de femeture pour Apple', fontsize=20)
plt.plot(df_stock)
plt.plot(ema)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Prix de fermeture ($)', fontsize=18)
plt.legend(['Données brutes','Moyenne mobile exponentielle'])
plt.show()

# %% [markdown]
# Nous ajoutons la moyenne mobile à notre dataframe :

# %%
df_train_rfe_et_close["moyenne_mobile"] = dataset_ema
# Out:
# /home/berrebi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_train_rfe_et_close.head()
# Out:
#    High_AAPL  Close_AAPL   Low_AAPL  Open_AAPL  Adj_Close_AAPL  Close_GOLD  \
# 0  14.732142   14.686786  14.607142  14.621428       12.566676   47.509998
# 1  14.810000   14.765715  14.617143  14.642858       12.634213   48.220001
# 2  14.948215   14.929643  14.738214  14.819643       12.774481   48.020000
# 3  15.098214   15.085714  14.972143  14.991786       12.908023   47.540001
# 4  15.276786   15.061786  15.048214  15.196428       12.887549   47.709999
#
#    Close_VIX  moyenne_mobile
# 0  22.969999       14.686786
# 1  22.219999       14.727039
# 2  21.480000       14.797293
# 3  20.629999       14.873781
# 4  21.070000       14.914449

# %%
corr_df = df_train_rfe_et_close.corr("pearson")

plt.figure(figsize=(25,14))
sn.heatmap(corr_df, annot=True)
plt.show()

# %% [markdown]
# ### Définition de Delta

# %% [markdown]
# Pour la suite, nous définissons un dataframe df avec les valeurs des deltas.

# %%
dt = (df_gafa_and_vix[["Close_AAPL"]].reset_index(drop=True))


yesterday_close_aapl = dt['Close_AAPL'].shift(1)

df_train_rfe_et_close["yesterday_close_AAPL"] = yesterday_close_aapl
df_train_rfe_et_close["delta"] = df_train_rfe_et_close["Close_AAPL"]-df_train_rfe_et_close["yesterday_close_AAPL"]

indice_nan = [0]
df_train_rfe_et_close.drop(indice_nan, 0, inplace = True)


df_train_rfe_et_close.head()
# Out:
# /home/berrebi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/berrebi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /home/berrebi/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    High_AAPL  Close_AAPL   Low_AAPL  Open_AAPL  Adj_Close_AAPL  Close_GOLD  \
# 1  14.810000   14.765715  14.617143  14.642858       12.634213   48.220001
# 2  14.948215   14.929643  14.738214  14.819643       12.774481   48.020000
# 3  15.098214   15.085714  14.972143  14.991786       12.908023   47.540001
# 4  15.276786   15.061786  15.048214  15.196428       12.887549   47.709999
# 5  15.214286   15.115714  15.053572  15.211071       12.933691   48.330002
#
#    Close_VIX  moyenne_mobile  yesterday_close_AAPL     delta
# 1  22.219999       14.727039             14.686786  0.078929
# 2  21.480000       14.797293             14.765715  0.163928
# 3  20.629999       14.873781             14.929643  0.156072
# 4  21.070000       14.914449             15.085714 -0.023929
# 5  20.690001       14.951435             15.061786  0.053928

# %% [markdown]
# *Nous utiliserons df pour la section 2 avec la prediction de delta*

# %%
df = df_train_rfe_et_close.copy()

# %% [markdown]
# ### y_naif
#
# Nous définissons une baseline qui consiste à prédire le prix de la veille pour le lendemain. Nous avons normalisé et nous obtenons la variable normalized_col_naif.

# %%
y_naif = df["yesterday_close_AAPL"].to_numpy()

data_stock_naif = df.filter(['yesterday_close_AAPL'])
dataset_stock_naif = data_stock_naif.values
scaler_stock_close_naif = MinMaxScaler(feature_range=(0,1))
normalized_col_naif = scaler_stock_close_naif.fit_transform(dataset_stock_naif)

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Paragraph sur le preprocess
# Et différence avec standardiser --> on a pas des données gaussiennes

# %%
def normalize_min_max(df, col):
    """
    Retourne : 
      Un array normalisée par la méthode Min Max de la colonne col du dataframe df

    Parametres d'entrées : 
      df : DataFrame  -> le dataframe des données 
      col : string    -> la colonne à normaliser
    
    """
    data = df.filter([col])
    dataset = data.values
    scaler = MinMaxScaler(feature_range=(0,1))
    normalized_col = scaler.fit_transform(dataset)
    
    return normalized_col, scaler

# %%
#Normalisation des données

## Pour le close on a besoin de garder en variable globale le feature_range=(0,1)
data_close = df_train_rfe_et_close.filter(['Close_AAPL'])
dataset_close = data_close.values
scaler_stock_close = MinMaxScaler(feature_range=(0,1))
normalized_close = scaler_stock_close.fit_transform(dataset_close)

scaled_close, scaler_close = normalize_min_max(df_train_rfe_et_close,'Close_AAPL')
scaled_open, scaler_open = normalize_min_max(df_train_rfe_et_close,'Open_AAPL')
scaled_adj, scaler_adj = normalize_min_max(df_train_rfe_et_close,'Adj_Close_AAPL')
scaled_high, scaler_high = normalize_min_max(df_train_rfe_et_close,'High_AAPL')
scaled_low, scaler_low = normalize_min_max(df_train_rfe_et_close,'Low_AAPL')
scaled_close_gold, scaler_close_gold = normalize_min_max(df_train_rfe_et_close,'Close_GOLD')
scaled_vix, scaler_vix = normalize_min_max(df_train_rfe_et_close,'Close_VIX')
scaled_ma, scaler_ma = normalize_min_max(df_train_rfe_et_close,'moyenne_mobile')

scaled_data=np.concatenate((scaled_close, scaled_open, scaled_adj, scaled_high, scaled_low, scaled_close_gold, scaled_vix, scaled_ma),axis=1)

# %%
scaled_data.shape
# Out:
# (1930, 8)

# %%
type(scaler_close)
# Out:
# sklearn.preprocessing._data.MinMaxScaler

# %% [markdown]
# ### Découpage des données en jeux de train et de test

# %%
#la proportion des données d'entrainement
prop_train_size= 0.7
# le nombre de variables explicatives
nb_columns = 8
# la taille des fenetres d'entrainement
time_step = 16
# la taille du jeu d'entrainement
training_data_len = int(len(df_train_rfe_et_close) * prop_train_size)

# %%
array_output = df_stock.values

# %%
def split_data(array_input, array_output, naif, prop_train_size, nb_columns):
    """
    Retourne : 
      Split le jeu de données en train, test à la fois pour les input, pour l'output, et pour la stratégie naive. L'ordre est conservé. 
    
    Parametres d'entrées :
      array_input : np.array  -> jeu de données d'input
      array_output : np.array -> jeu de données d'output
      naif : np.array         -> jeu de données naif
      prop_train_size : float -> proportion du jeu d'entrainement
      nb_columns : int        -> nombre de features 
    
    """    
    n = len(array_output)
    training_size = int(n*prop_train_size)
    test_size = n- training_size
    
    array_split_input_train= array_input[:training_size].reshape(-1,nb_columns)
    array_split_input_test = array_input[training_size:].reshape(-1,nb_columns)
    
    array_split_output_train = array_output[:training_size].reshape(-1,1)
    array_split_output_test = array_output[training_size:].reshape(-1,1)

    array_naif_train =  naif[:training_size].reshape(-1,1)
    array_naif_test = naif[training_size:].reshape(-1,1)
    
    return array_split_input_train, array_split_input_test, array_split_output_train, array_split_output_test, array_naif_train, array_naif_test

def create_windows_data_XandY(array_split_input, array_split_output, time_step, array_naif ):
    """
    Retourne : Jeux de données train,test et naif avec des fenetres flissantes de taille time_step
      
    
    Parametres d'entrées :
      array_split_input : np.array          -> jeu de donnée d'input, idéalement un des deux sorti par la fonction split_data
      array_split_output : np.array         -> jeu de donnée d'output, idéalement celui sorti par la fonction split_data
      time_step : int                       ->
      array_naif : np.array                 ->

    """
    dataX = []
    dataY = []
    y_naif = []
    
    for i in range(len(array_split_output)- time_step - 1) : 
        set_value = array_split_input[i : (i+time_step) ,:]
        dataX.append(set_value)
        dataY.append(array_split_output[i + time_step])
        y_naif.append(array_naif[i + time_step])

    return np.array(dataX), np.array(dataY), np.array(y_naif)

# %%
train_data_input, test_data_input ,train_data_output, test_data_output, naif_train, naif_test = split_data(scaled_data, scaled_close, normalized_col_naif, prop_train_size, nb_columns)
X_train, Y_train, naif_train_windows= create_windows_data_XandY(train_data_input, train_data_output, time_step, naif_train)
X_test, Y_test , naif_test_windows= create_windows_data_XandY(test_data_input, test_data_output, time_step, naif_test)

# %%
print(train_data_input.shape)
print(test_data_input.shape)
print(type(train_data_input))
print(type(test_data_input))

print(train_data_output.shape)
print(test_data_output.shape)
print(type(train_data_output))
print(type(test_data_output))
# Out:
# (1351, 8)
# (579, 8)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (1351, 1)
# (579, 1)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (1334, 16, 8)
# (1334, 1)

# %% [markdown]
# ### Définition des modèles

# %% [markdown]
# Il y a beaucoup d'hyperparamètres dans ce modèle. Mis a part les hyperparamètres classiques (learning rate, fonctions d'activation, fonctions de coût, nombre de couches cachées, nombre de neurones par couche, la taille des batches..), nous avons aussi le nombre de jour de la fenêtre glissante (time_step) qui détient un role important.
#
# Nous avions eu au départ beaucoup d'overfitting, et le modèle ne semblait pas du tout apprendre (le graph des fonctions de coût du train et de la validation donnait systématiquement deux droites presque parrallèles et très eloignées). Dans un tel cas où le modèle n'apprend pas, nous avons décidé de modifier les paramètres par défaut de l'optimiser Adam pour sélectionner un learning rate idéal. En effet celui par défaut était trop grand (de l'ordre de  1e-2) et nous avons finalement choisi un learning rate de l'ordre de 1e-4. Suite à ce choix, la courbe de la loss validation commençait enfin à décroitre ! Première victoire mais cependant, la courbe de la loss du train restait constante. Nous avions donc de l'overfitting. Pour cela nous avons ajouté deux couches de Dropout de probabilité 0.2, et nous avons diminué le nombre de jour de la fenêtre à 32. Nous obtenons enfin un modèle cohérent (mais encore loin d'être parfait). Il faut bien sûr ajouter à cela la difficulté de prédire le cours d'une action même hors coronavirus et la faible quantité des données.

# %% [markdown]
# #### Modèle 1 : batch_size = 16

# %%
model = Sequential()


model.add(LSTM(64, return_sequences=False,input_shape=(time_step,nb_columns)))
model.add(Dropout(0.2))

model.add(Dense(64, activation = "relu"))
model.add(Dropout(0.2))

model.add(Dense(1, activation = "linear"))

# %%
#Optimizer Adam modifié 
adam = keras.optimizers.Adam(lr=1e-4, beta_1=0.9, beta_2 = 0.999, epsilon =1e-8)

#Compilation
model.compile(optimizer=adam, loss='mean_squared_error', metrics = ["mae"])

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_13 (LSTM)               (None, 64)                18688
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 22,913
# Trainable params: 22,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Phase d'apprentissage

# %%
model.fit(X_train, Y_train, validation_data = (X_test, Y_test),  verbose=1)
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test),  epochs = 200, batch_size=16)
# Out:
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0196 - mae: 0.1080 - val_loss: 0.0613 - val_mae: 0.2337
# Epoch 1/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0049 - mae: 0.0543 - val_loss: 0.0086 - val_mae: 0.0785
# Epoch 2/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0034 - mae: 0.0452 - val_loss: 0.0109 - val_mae: 0.0906
# Epoch 3/200
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0032 - mae: 0.0421 - val_loss: 0.0049 - val_mae: 0.0580
# Epoch 4/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0027 - mae: 0.0389 - val_loss: 0.0045 - val_mae: 0.0557
# Epoch 5/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0024 - mae: 0.0367 - val_loss: 0.0055 - val_mae: 0.0627
# Epoch 6/200
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0022 - mae: 0.0350 - val_loss: 0.0042 - val_mae: 0.0539
# Epoch 7/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0021 - mae: 0.0344 - val_loss: 0.0033 - val_mae: 0.0471
# Epoch 8/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0020 - mae: 0.0335 - val_loss: 0.0034 - val_mae: 0.0482
# Epoch 9/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0020 - mae: 0.0329 - val_loss: 0.0052 - val_mae: 0.0608
# Epoch 10/200
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0020 - mae: 0.0327 - val_loss: 0.0050 - val_mae: 0.0596
# Epoch 11/200
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0018 - mae: 0.0319 - val_loss: 0.0031 - val_mae: 0.0457
# Epoch 12/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0017 - mae: 0.0311 - val_loss: 0.0051 - val_mae: 0.0608
# Epoch 13/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0017 - mae: 0.0310 - val_loss: 0.0028 - val_mae: 0.0435
# Epoch 14/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0016 - mae: 0.0300 - val_loss: 0.0055 - val_mae: 0.0640
# Epoch 15/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0015 - mae: 0.0288 - val_loss: 0.0033 - val_mae: 0.0479
# Epoch 16/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0015 - mae: 0.0284 - val_loss: 0.0031 - val_mae: 0.0467
# Epoch 17/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0014 - mae: 0.0274 - val_loss: 0.0022 - val_mae: 0.0384
# Epoch 18/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0015 - mae: 0.0289 - val_loss: 0.0037 - val_mae: 0.0515
# Epoch 19/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0014 - mae: 0.0281 - val_loss: 0.0042 - val_mae: 0.0549
# Epoch 20/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0013 - mae: 0.0276 - val_loss: 0.0040 - val_mae: 0.0534
# Epoch 21/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0013 - mae: 0.0272 - val_loss: 0.0049 - val_mae: 0.0607
# Epoch 22/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0013 - mae: 0.0269 - val_loss: 0.0039 - val_mae: 0.0529
# Epoch 23/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0013 - mae: 0.0262 - val_loss: 0.0017 - val_mae: 0.0329
# Epoch 24/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0013 - mae: 0.0272 - val_loss: 0.0044 - val_mae: 0.0573
# Epoch 25/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0012 - mae: 0.0265 - val_loss: 0.0026 - val_mae: 0.0422
# Epoch 26/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0012 - mae: 0.0260 - val_loss: 0.0042 - val_mae: 0.0561
# Epoch 27/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0012 - mae: 0.0256 - val_loss: 0.0020 - val_mae: 0.0366
# Epoch 28/200
# 84/84 [==============================] - 0s 6ms/step - loss: 0.0011 - mae: 0.0254 - val_loss: 0.0040 - val_mae: 0.0542
# Epoch 29/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0012 - mae: 0.0253 - val_loss: 0.0040 - val_mae: 0.0548
# Epoch 30/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0011 - mae: 0.0249 - val_loss: 0.0035 - val_mae: 0.0506
# Epoch 31/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0011 - mae: 0.0248 - val_loss: 0.0056 - val_mae: 0.0663
# Epoch 32/200
# 84/84 [==============================] - 0s 6ms/step - loss: 0.0011 - mae: 0.0246 - val_loss: 0.0031 - val_mae: 0.0473
# Epoch 33/200
# 84/84 [==============================] - 1s 6ms/step - loss: 9.6389e-04 - mae: 0.0234 - val_loss: 0.0044 - val_mae: 0.0579
# Epoch 34/200
# 84/84 [==============================] - 0s 6ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 0.0047 - val_mae: 0.0605
# Epoch 35/200
# 84/84 [==============================] - 0s 5ms/step - loss: 9.5840e-04 - mae: 0.0232 - val_loss: 0.0021 - val_mae: 0.0379
# Epoch 36/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0010 - mae: 0.0239 - val_loss: 0.0022 - val_mae: 0.0386
# Epoch 37/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0010 - mae: 0.0238 - val_loss: 0.0017 - val_mae: 0.0341
# Epoch 38/200
# 84/84 [==============================] - 0s 4ms/step - loss: 9.1631e-04 - mae: 0.0227 - val_loss: 0.0036 - val_mae: 0.0522
# Epoch 39/200
# 84/84 [==============================] - 0s 5ms/step - loss: 9.1702e-04 - mae: 0.0229 - val_loss: 0.0018 - val_mae: 0.0345
# Epoch 40/200
# 84/84 [==============================] - 0s 4ms/step - loss: 9.4215e-04 - mae: 0.0223 - val_loss: 0.0019 - val_mae: 0.0357
# Epoch 41/200
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0010 - mae: 0.0234 - val_loss: 0.0027 - val_mae: 0.0450
# Epoch 42/200
# 84/84 [==============================] - 0s 4ms/step - loss: 8.8895e-04 - mae: 0.0221 - val_loss: 0.0014 - val_mae: 0.0307
# Epoch 43/200
# 84/84 [==============================] - 0s 4ms/step - loss: 9.0865e-04 - mae: 0.0221 - val_loss: 0.0020 - val_mae: 0.0375
# Epoch 44/200
# 84/84 [==============================] - 0s 5ms/step - loss: 8.8929e-04 - mae: 0.0219 - val_loss: 0.0025 - val_mae: 0.0422
# Epoch 45/200
# 84/84 [==============================] - 0s 4ms/step - loss: 8.2616e-04 - mae: 0.0218 - val_loss: 0.0019 - val_mae: 0.0360
# Epoch 46/200
# 84/84 [==============================] - 0s 5ms/step - loss: 8.6831e-04 - mae: 0.0221 - val_loss: 7.5612e-04 - val_mae: 0.0209
# Epoch 47/200
# 84/84 [==============================] - 0s 5ms/step - loss: 8.9106e-04 - mae: 0.0221 - val_loss: 0.0037 - val_mae: 0.0543
# Epoch 48/200
# 84/84 [==============================] - 0s 5ms/step - loss: 8.0557e-04 - mae: 0.0211 - val_loss: 0.0016 - val_mae: 0.0327
# Epoch 49/200
# 84/84 [==============================] - 0s 5ms/step - loss: 8.1671e-04 - mae: 0.0212 - val_loss: 0.0013 - val_mae: 0.0297
# Epoch 50/200
# 84/84 [==============================] - 0s 5ms/step - loss: 8.3644e-04 - mae: 0.0216 - val_loss: 0.0015 - val_mae: 0.0321
# Epoch 51/200
# 84/84 [==============================] - 0s 5ms/step - loss: 8.2034e-04 - mae: 0.0210 - val_loss: 0.0021 - val_mae: 0.0390
# Epoch 52/200
# 84/84 [==============================] - 0s 5ms/step - loss: 8.1492e-04 - mae: 0.0209 - val_loss: 9.2044e-04 - val_mae: 0.0238
# Epoch 53/200
# 84/84 [==============================] - 0s 5ms/step - loss: 8.4141e-04 - mae: 0.0213 - val_loss: 9.7852e-04 - val_mae: 0.0248
# Epoch 54/200
# 84/84 [==============================] - 0s 5ms/step - loss: 8.0999e-04 - mae: 0.0214 - val_loss: 7.0765e-04 - val_mae: 0.0201
# Epoch 55/200
# 84/84 [==============================] - 0s 5ms/step - loss: 7.4150e-04 - mae: 0.0201 - val_loss: 0.0015 - val_mae: 0.0316
# Epoch 56/200
# 84/84 [==============================] - 0s 5ms/step - loss: 7.1696e-04 - mae: 0.0203 - val_loss: 0.0012 - val_mae: 0.0279
# Epoch 57/200
# 84/84 [==============================] - 0s 5ms/step - loss: 7.2953e-04 - mae: 0.0199 - val_loss: 0.0019 - val_mae: 0.0363
# Epoch 58/200
# 84/84 [==============================] - 0s 5ms/step - loss: 7.9333e-04 - mae: 0.0205 - val_loss: 0.0011 - val_mae: 0.0265
# Epoch 59/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.9172e-04 - mae: 0.0196 - val_loss: 0.0031 - val_mae: 0.0491
# Epoch 60/200
# 84/84 [==============================] - 0s 5ms/step - loss: 7.3766e-04 - mae: 0.0201 - val_loss: 0.0014 - val_mae: 0.0308
# Epoch 61/200
# 84/84 [==============================] - 0s 5ms/step - loss: 7.3760e-04 - mae: 0.0199 - val_loss: 0.0012 - val_mae: 0.0277
# Epoch 62/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.8735e-04 - mae: 0.0193 - val_loss: 8.2028e-04 - val_mae: 0.0223
# Epoch 63/200
# 84/84 [==============================] - 0s 5ms/step - loss: 7.2228e-04 - mae: 0.0199 - val_loss: 0.0012 - val_mae: 0.0281
# Epoch 64/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.5367e-04 - mae: 0.0192 - val_loss: 0.0011 - val_mae: 0.0268
# Epoch 65/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.8157e-04 - mae: 0.0196 - val_loss: 0.0024 - val_mae: 0.0431
# Epoch 66/200
# 84/84 [==============================] - 0s 5ms/step - loss: 7.3964e-04 - mae: 0.0199 - val_loss: 7.4187e-04 - val_mae: 0.0209
# Epoch 67/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.5049e-04 - mae: 0.0190 - val_loss: 6.7246e-04 - val_mae: 0.0196
# Epoch 68/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.7577e-04 - mae: 0.0192 - val_loss: 0.0013 - val_mae: 0.0298
# Epoch 69/200
# 84/84 [==============================] - 0s 4ms/step - loss: 6.5146e-04 - mae: 0.0188 - val_loss: 8.0442e-04 - val_mae: 0.0221
# Epoch 70/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.5780e-04 - mae: 0.0190 - val_loss: 7.3301e-04 - val_mae: 0.0208
# Epoch 71/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.5085e-04 - mae: 0.0193 - val_loss: 6.7798e-04 - val_mae: 0.0197
# Epoch 72/200
# 84/84 [==============================] - 0s 6ms/step - loss: 6.2242e-04 - mae: 0.0187 - val_loss: 6.6442e-04 - val_mae: 0.0195
# Epoch 73/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.7344e-04 - mae: 0.0193 - val_loss: 6.9793e-04 - val_mae: 0.0202
# Epoch 74/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.2305e-04 - mae: 0.0189 - val_loss: 7.2746e-04 - val_mae: 0.0207
# Epoch 75/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.1730e-04 - mae: 0.0189 - val_loss: 6.0740e-04 - val_mae: 0.0184
# Epoch 76/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.2209e-04 - mae: 0.0191 - val_loss: 0.0014 - val_mae: 0.0315
# Epoch 77/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.9770e-04 - mae: 0.0182 - val_loss: 0.0013 - val_mae: 0.0295
# Epoch 78/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.4676e-04 - mae: 0.0189 - val_loss: 0.0011 - val_mae: 0.0268
# Epoch 79/200
# 84/84 [==============================] - 0s 5ms/step - loss: 6.3950e-04 - mae: 0.0186 - val_loss: 0.0010 - val_mae: 0.0258
# Epoch 80/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.3149e-04 - mae: 0.0171 - val_loss: 0.0013 - val_mae: 0.0306
# Epoch 81/200
# 84/84 [==============================] - 0s 4ms/step - loss: 5.6488e-04 - mae: 0.0177 - val_loss: 6.5271e-04 - val_mae: 0.0194
# Epoch 82/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.7428e-04 - mae: 0.0181 - val_loss: 0.0011 - val_mae: 0.0277
# Epoch 83/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.8762e-04 - mae: 0.0183 - val_loss: 7.9003e-04 - val_mae: 0.0219
# Epoch 84/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.4489e-04 - mae: 0.0174 - val_loss: 5.8420e-04 - val_mae: 0.0180
# Epoch 85/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.8185e-04 - mae: 0.0181 - val_loss: 8.2256e-04 - val_mae: 0.0226
# Epoch 86/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.5680e-04 - mae: 0.0178 - val_loss: 9.7800e-04 - val_mae: 0.0252
# Epoch 87/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.3152e-04 - mae: 0.0173 - val_loss: 0.0014 - val_mae: 0.0310
# Epoch 88/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.5415e-04 - mae: 0.0173 - val_loss: 0.0010 - val_mae: 0.0259
# Epoch 89/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.3492e-04 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0306
# Epoch 90/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.3898e-04 - mae: 0.0174 - val_loss: 6.7586e-04 - val_mae: 0.0198
# Epoch 91/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.5106e-04 - mae: 0.0175 - val_loss: 0.0011 - val_mae: 0.0277
# Epoch 92/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.5652e-04 - mae: 0.0172 - val_loss: 6.3465e-04 - val_mae: 0.0191
# Epoch 93/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.8969e-04 - mae: 0.0168 - val_loss: 7.2888e-04 - val_mae: 0.0209
# Epoch 94/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.4349e-04 - mae: 0.0171 - val_loss: 5.8509e-04 - val_mae: 0.0181
# Epoch 95/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.0542e-04 - mae: 0.0167 - val_loss: 7.8104e-04 - val_mae: 0.0219
# Epoch 96/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.5759e-04 - mae: 0.0175 - val_loss: 8.0324e-04 - val_mae: 0.0224
# Epoch 97/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.2456e-04 - mae: 0.0172 - val_loss: 5.7442e-04 - val_mae: 0.0179
# Epoch 98/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.8219e-04 - mae: 0.0167 - val_loss: 0.0012 - val_mae: 0.0282
# Epoch 99/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.1570e-04 - mae: 0.0170 - val_loss: 0.0016 - val_mae: 0.0348
# Epoch 100/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.7229e-04 - mae: 0.0163 - val_loss: 9.8824e-04 - val_mae: 0.0255
# Epoch 101/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.8190e-04 - mae: 0.0163 - val_loss: 0.0015 - val_mae: 0.0335
# Epoch 102/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.0738e-04 - mae: 0.0169 - val_loss: 0.0013 - val_mae: 0.0303
# Epoch 103/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.6014e-04 - mae: 0.0161 - val_loss: 0.0010 - val_mae: 0.0259
# Epoch 104/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.4102e-04 - mae: 0.0171 - val_loss: 0.0010 - val_mae: 0.0258
# Epoch 105/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.6313e-04 - mae: 0.0161 - val_loss: 5.7310e-04 - val_mae: 0.0179
# Epoch 106/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.7683e-04 - mae: 0.0168 - val_loss: 5.8644e-04 - val_mae: 0.0182
# Epoch 107/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.7930e-04 - mae: 0.0166 - val_loss: 6.3310e-04 - val_mae: 0.0191
# Epoch 108/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.8058e-04 - mae: 0.0165 - val_loss: 7.1125e-04 - val_mae: 0.0207
# Epoch 109/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.9187e-04 - mae: 0.0165 - val_loss: 5.5092e-04 - val_mae: 0.0175
# Epoch 110/200
# 84/84 [==============================] - 0s 5ms/step - loss: 5.0396e-04 - mae: 0.0168 - val_loss: 0.0013 - val_mae: 0.0298
# Epoch 111/200
# 84/84 [==============================] - 0s 6ms/step - loss: 4.7681e-04 - mae: 0.0163 - val_loss: 5.6434e-04 - val_mae: 0.0178
# Epoch 112/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.5434e-04 - mae: 0.0160 - val_loss: 7.7981e-04 - val_mae: 0.0220
# Epoch 113/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.3477e-04 - mae: 0.0157 - val_loss: 6.4003e-04 - val_mae: 0.0193
# Epoch 114/200
# 84/84 [==============================] - 0s 4ms/step - loss: 4.5143e-04 - mae: 0.0160 - val_loss: 7.9049e-04 - val_mae: 0.0223
# Epoch 115/200
# 84/84 [==============================] - 0s 4ms/step - loss: 4.9575e-04 - mae: 0.0164 - val_loss: 6.5041e-04 - val_mae: 0.0194
# Epoch 116/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.7048e-04 - mae: 0.0162 - val_loss: 0.0014 - val_mae: 0.0316
# Epoch 117/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.9115e-04 - mae: 0.0167 - val_loss: 9.2639e-04 - val_mae: 0.0247
# Epoch 118/200
# 84/84 [==============================] - 0s 4ms/step - loss: 4.6985e-04 - mae: 0.0161 - val_loss: 0.0011 - val_mae: 0.0271
# Epoch 119/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.5964e-04 - mae: 0.0160 - val_loss: 8.9146e-04 - val_mae: 0.0241
# Epoch 120/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.2188e-04 - mae: 0.0153 - val_loss: 5.7040e-04 - val_mae: 0.0179
# Epoch 121/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.5371e-04 - mae: 0.0159 - val_loss: 0.0013 - val_mae: 0.0304
# Epoch 122/200
# 84/84 [==============================] - 0s 4ms/step - loss: 4.9001e-04 - mae: 0.0165 - val_loss: 0.0014 - val_mae: 0.0313
# Epoch 123/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.4896e-04 - mae: 0.0161 - val_loss: 0.0011 - val_mae: 0.0278
# Epoch 124/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.5236e-04 - mae: 0.0159 - val_loss: 0.0012 - val_mae: 0.0294
# Epoch 125/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.0563e-04 - mae: 0.0153 - val_loss: 5.1024e-04 - val_mae: 0.0167
# Epoch 126/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.2496e-04 - mae: 0.0155 - val_loss: 5.1364e-04 - val_mae: 0.0168
# Epoch 127/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.4381e-04 - mae: 0.0158 - val_loss: 0.0014 - val_mae: 0.0321
# Epoch 128/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.8205e-04 - mae: 0.0147 - val_loss: 6.5918e-04 - val_mae: 0.0198
# Epoch 129/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.3991e-04 - mae: 0.0157 - val_loss: 7.8567e-04 - val_mae: 0.0222
# Epoch 130/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.3362e-04 - mae: 0.0155 - val_loss: 5.3191e-04 - val_mae: 0.0173
# Epoch 131/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.3098e-04 - mae: 0.0154 - val_loss: 7.7078e-04 - val_mae: 0.0221
# Epoch 132/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.1394e-04 - mae: 0.0155 - val_loss: 0.0012 - val_mae: 0.0290
# Epoch 133/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.2383e-04 - mae: 0.0155 - val_loss: 0.0015 - val_mae: 0.0336
# Epoch 134/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.7251e-04 - mae: 0.0148 - val_loss: 0.0012 - val_mae: 0.0297
# Epoch 135/200
# 84/84 [==============================] - 0s 6ms/step - loss: 4.0130e-04 - mae: 0.0152 - val_loss: 4.8489e-04 - val_mae: 0.0163
# Epoch 136/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.1337e-04 - mae: 0.0151 - val_loss: 8.9440e-04 - val_mae: 0.0244
# Epoch 137/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.0333e-04 - mae: 0.0152 - val_loss: 7.4087e-04 - val_mae: 0.0217
# Epoch 138/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.1458e-04 - mae: 0.0154 - val_loss: 5.0307e-04 - val_mae: 0.0167
# Epoch 139/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.3828e-04 - mae: 0.0155 - val_loss: 6.9905e-04 - val_mae: 0.0209
# Epoch 140/200
# 84/84 [==============================] - 0s 6ms/step - loss: 4.0699e-04 - mae: 0.0152 - val_loss: 6.0619e-04 - val_mae: 0.0190
# Epoch 141/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.3129e-04 - mae: 0.0151 - val_loss: 4.7549e-04 - val_mae: 0.0161
# Epoch 142/200
# 84/84 [==============================] - 0s 6ms/step - loss: 3.8541e-04 - mae: 0.0146 - val_loss: 0.0010 - val_mae: 0.0267
# Epoch 143/200
# 84/84 [==============================] - 0s 6ms/step - loss: 3.9378e-04 - mae: 0.0148 - val_loss: 4.8624e-04 - val_mae: 0.0164
# Epoch 144/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.7911e-04 - mae: 0.0148 - val_loss: 6.2764e-04 - val_mae: 0.0194
# Epoch 145/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.3670e-04 - mae: 0.0156 - val_loss: 4.8203e-04 - val_mae: 0.0163
# Epoch 146/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.0536e-04 - mae: 0.0150 - val_loss: 4.6497e-04 - val_mae: 0.0159
# Epoch 147/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.0983e-04 - mae: 0.0152 - val_loss: 4.8557e-04 - val_mae: 0.0164
# Epoch 148/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.9298e-04 - mae: 0.0150 - val_loss: 4.8506e-04 - val_mae: 0.0164
# Epoch 149/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.9735e-04 - mae: 0.0151 - val_loss: 4.7932e-04 - val_mae: 0.0163
# Epoch 150/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.1888e-04 - mae: 0.0156 - val_loss: 9.2221e-04 - val_mae: 0.0242
# Epoch 151/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.8784e-04 - mae: 0.0147 - val_loss: 5.1127e-04 - val_mae: 0.0166
# Epoch 152/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.2721e-04 - mae: 0.0153 - val_loss: 8.4717e-04 - val_mae: 0.0239
# Epoch 153/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.9870e-04 - mae: 0.0148 - val_loss: 5.3567e-04 - val_mae: 0.0175
# Epoch 154/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.0052e-04 - mae: 0.0150 - val_loss: 5.0655e-04 - val_mae: 0.0169
# Epoch 155/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.0569e-04 - mae: 0.0150 - val_loss: 7.4953e-04 - val_mae: 0.0218
# Epoch 156/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.8334e-04 - mae: 0.0146 - val_loss: 5.4736e-04 - val_mae: 0.0177
# Epoch 157/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.6666e-04 - mae: 0.0144 - val_loss: 6.3713e-04 - val_mae: 0.0198
# Epoch 158/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.5839e-04 - mae: 0.0144 - val_loss: 8.5180e-04 - val_mae: 0.0238
# Epoch 159/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.5222e-04 - mae: 0.0141 - val_loss: 4.5974e-04 - val_mae: 0.0159
# Epoch 160/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.5122e-04 - mae: 0.0142 - val_loss: 4.7430e-04 - val_mae: 0.0161
# Epoch 161/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.0525e-04 - mae: 0.0149 - val_loss: 4.5950e-04 - val_mae: 0.0158
# Epoch 162/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.9271e-04 - mae: 0.0148 - val_loss: 7.3163e-04 - val_mae: 0.0217
# Epoch 163/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.8940e-04 - mae: 0.0149 - val_loss: 4.5612e-04 - val_mae: 0.0158
# Epoch 164/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.8526e-04 - mae: 0.0147 - val_loss: 6.9480e-04 - val_mae: 0.0210
# Epoch 165/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.7890e-04 - mae: 0.0147 - val_loss: 4.6653e-04 - val_mae: 0.0159
# Epoch 166/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.8384e-04 - mae: 0.0147 - val_loss: 4.4942e-04 - val_mae: 0.0156
# Epoch 167/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.9020e-04 - mae: 0.0149 - val_loss: 6.0466e-04 - val_mae: 0.0192
# Epoch 168/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.9373e-04 - mae: 0.0150 - val_loss: 4.4495e-04 - val_mae: 0.0155
# Epoch 169/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.7602e-04 - mae: 0.0148 - val_loss: 5.2884e-04 - val_mae: 0.0172
# Epoch 170/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.8517e-04 - mae: 0.0148 - val_loss: 6.4043e-04 - val_mae: 0.0194
# Epoch 171/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.6576e-04 - mae: 0.0146 - val_loss: 7.9746e-04 - val_mae: 0.0230
# Epoch 172/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.9483e-04 - mae: 0.0148 - val_loss: 4.4209e-04 - val_mae: 0.0154
# Epoch 173/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.7325e-04 - mae: 0.0146 - val_loss: 4.6027e-04 - val_mae: 0.0160
# Epoch 174/200
# 84/84 [==============================] - 0s 5ms/step - loss: 4.0359e-04 - mae: 0.0151 - val_loss: 7.8023e-04 - val_mae: 0.0228
# Epoch 175/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.7149e-04 - mae: 0.0145 - val_loss: 5.0668e-04 - val_mae: 0.0171
# Epoch 176/200
# 84/84 [==============================] - 0s 6ms/step - loss: 3.3695e-04 - mae: 0.0139 - val_loss: 4.9081e-04 - val_mae: 0.0162
# Epoch 177/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.6344e-04 - mae: 0.0147 - val_loss: 4.4914e-04 - val_mae: 0.0154
# Epoch 178/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.6366e-04 - mae: 0.0145 - val_loss: 5.3942e-04 - val_mae: 0.0179
# Epoch 179/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.3894e-04 - mae: 0.0140 - val_loss: 0.0012 - val_mae: 0.0296
# Epoch 180/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.6091e-04 - mae: 0.0142 - val_loss: 5.2154e-04 - val_mae: 0.0175
# Epoch 181/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.8463e-04 - mae: 0.0148 - val_loss: 4.5260e-04 - val_mae: 0.0158
# Epoch 182/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.4718e-04 - mae: 0.0139 - val_loss: 7.0570e-04 - val_mae: 0.0215
# Epoch 183/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.6002e-04 - mae: 0.0140 - val_loss: 9.7422e-04 - val_mae: 0.0262
# Epoch 184/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.6713e-04 - mae: 0.0146 - val_loss: 5.0252e-04 - val_mae: 0.0164
# Epoch 185/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.4940e-04 - mae: 0.0142 - val_loss: 0.0012 - val_mae: 0.0304
# Epoch 186/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.7031e-04 - mae: 0.0146 - val_loss: 5.3592e-04 - val_mae: 0.0179
# Epoch 187/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.3861e-04 - mae: 0.0138 - val_loss: 4.8849e-04 - val_mae: 0.0167
# Epoch 188/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.3978e-04 - mae: 0.0140 - val_loss: 6.5649e-04 - val_mae: 0.0205
# Epoch 189/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.4324e-04 - mae: 0.0140 - val_loss: 4.2676e-04 - val_mae: 0.0150
# Epoch 190/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.6013e-04 - mae: 0.0142 - val_loss: 4.5653e-04 - val_mae: 0.0160
# Epoch 191/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.4642e-04 - mae: 0.0139 - val_loss: 6.4953e-04 - val_mae: 0.0204
# Epoch 192/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.6370e-04 - mae: 0.0142 - val_loss: 4.6483e-04 - val_mae: 0.0157
# Epoch 193/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.5002e-04 - mae: 0.0141 - val_loss: 4.3398e-04 - val_mae: 0.0153
# Epoch 194/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.4893e-04 - mae: 0.0142 - val_loss: 4.3992e-04 - val_mae: 0.0156
# Epoch 195/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.3598e-04 - mae: 0.0137 - val_loss: 8.5306e-04 - val_mae: 0.0243
# Epoch 196/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.3689e-04 - mae: 0.0139 - val_loss: 4.3656e-04 - val_mae: 0.0151
# Epoch 197/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.2183e-04 - mae: 0.0137 - val_loss: 4.2780e-04 - val_mae: 0.0151
# Epoch 198/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.3853e-04 - mae: 0.0140 - val_loss: 5.1730e-04 - val_mae: 0.0168
# Epoch 199/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.3642e-04 - mae: 0.0138 - val_loss: 4.4070e-04 - val_mae: 0.0156
# Epoch 200/200
# 84/84 [==============================] - 0s 5ms/step - loss: 3.3132e-04 - mae: 0.0138 - val_loss: 4.5118e-04 - val_mae: 0.0159

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
mae = history_dict['mae']
val_mae = history_dict['val_mae']
 
epochs = range(1, len(loss_values) + 1)
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

ax[0].plot(epochs, mae, 'bo', label='Training mae')
ax[0].plot(epochs, val_mae, 'b', label='Validation mae')
ax[0].set_title('Training &amp; Validation mae', fontsize=16)
ax[0].set_xlabel('Epochs', fontsize=16)
ax[0].set_ylabel('mae', fontsize=16)
ax[0].legend()
 
ax[1].plot(epochs, loss_values, 'bo', label='Training loss') 
ax[1].plot(epochs, val_loss_values, 'b', label='Validation loss')
ax[1].set_title('Training &amp; Validation Loss', fontsize=16)
ax[1].set_xlabel('Epochs', fontsize=16)
ax[1].set_ylabel('Loss', fontsize=16)
ax[1].legend()

# %%
#Après modification du learning rate

# %% [markdown]
# #### Modele 2 batch_size = 4

# %%
model2 = Sequential()


model2.add(LSTM(64, return_sequences=False,input_shape=(time_step,nb_columns)))
model2.add(Dropout(0.2))
model2.add(Dense(64, activation = "relu"))
model2.add(Dropout(0.2))
model2.add(Dense(1, activation = "linear"))

#optimizer
adam2 = keras.optimizers.Adam(lr=1e-4, beta_1=0.9, beta_2 = 0.999, epsilon =1e-8)

#compilation
model2.compile(optimizer=adam2, loss='mean_squared_error', metrics = ["mae"])

model2.summary()

model2.fit(X_train, Y_train, validation_data = (X_test, Y_test),  verbose=1)
history2 = model2.fit(X_train, Y_train, validation_data=(X_test, Y_test),  epochs = 200, batch_size=4)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 64)                18688
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_37 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 22,913
# Trainable params: 22,913
# Non-trainable params: 0
# _________________________________________________________________
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0257 - mae: 0.1283 - val_loss: 0.0292 - val_mae: 0.1582
# Epoch 1/200
# 334/334 [==============================] - 2s 5ms/step - loss: 0.0046 - mae: 0.0503 - val_loss: 0.0040 - val_mae: 0.0527
# Epoch 2/200
# 334/334 [==============================] - 2s 4ms/step - loss: 0.0032 - mae: 0.0418 - val_loss: 0.0028 - val_mae: 0.0435
# Epoch 3/200
# 334/334 [==============================] - 2s 5ms/step - loss: 0.0025 - mae: 0.0370 - val_loss: 0.0031 - val_mae: 0.0465
# Epoch 4/200
# 334/334 [==============================] - 2s 5ms/step - loss: 0.0023 - mae: 0.0353 - val_loss: 0.0019 - val_mae: 0.0357
# Epoch 5/200
# 334/334 [==============================] - 2s 5ms/step - loss: 0.0023 - mae: 0.0359 - val_loss: 0.0027 - val_mae: 0.0426
# Epoch 6/200
# 334/334 [==============================] - 2s 5ms/step - loss: 0.0017 - mae: 0.0314 - val_loss: 0.0026 - val_mae: 0.0420
# Epoch 7/200
# 334/334 [==============================] - 2s 5ms/step - loss: 0.0016 - mae: 0.0302 - val_loss: 0.0035 - val_mae: 0.0503
# Epoch 8/200
# 334/334 [==============================] - 2s 5ms/step - loss: 0.0016 - mae: 0.0298 - val_loss: 0.0017 - val_mae: 0.0336
# Epoch 9/200
# 334/334 [==============================] - 2s 5ms/step - loss: 0.0014 - mae: 0.0277 - val_loss: 0.0024 - val_mae: 0.0404
# Epoch 10/200
# 334/334 [==============================] - 2s 5ms/step - loss: 0.0015 - mae: 0.0280 - val_loss: 0.0024 - val_mae: 0.0407
# Epoch 11/200
# 334/334 [==============================] - 2s 5ms/step - loss: 0.0013 - mae: 0.0264 - val_loss: 0.0029 - val_mae: 0.0460
# Epoch 12/200
# 334/334 [==============================] - 2s 5ms/step - loss: 0.0013 - mae: 0.0263 - val_loss: 0.0034 - val_mae: 0.0510
# Epoch 13/200
# 334/334 [==============================] - 2s 5ms/step - loss: 0.0011 - mae: 0.0246 - val_loss: 0.0016 - val_mae: 0.0325
# Epoch 14/200
# 334/334 [==============================] - 1s 4ms/step - loss: 0.0011 - mae: 0.0243 - val_loss: 0.0023 - val_mae: 0.0404
# Epoch 15/200
# 334/334 [==============================] - 2s 5ms/step - loss: 9.7930e-04 - mae: 0.0229 - val_loss: 0.0017 - val_mae: 0.0340
# Epoch 16/200
# 334/334 [==============================] - 2s 5ms/step - loss: 9.4497e-04 - mae: 0.0226 - val_loss: 0.0019 - val_mae: 0.0368
# Epoch 17/200
# 334/334 [==============================] - 2s 5ms/step - loss: 9.6293e-04 - mae: 0.0230 - val_loss: 7.8835e-04 - val_mae: 0.0214
# Epoch 18/200
# 334/334 [==============================] - 2s 4ms/step - loss: 0.0010 - mae: 0.0235 - val_loss: 0.0021 - val_mae: 0.0395
# Epoch 19/200
# 334/334 [==============================] - 2s 5ms/step - loss: 8.3979e-04 - mae: 0.0218 - val_loss: 0.0014 - val_mae: 0.0299
# Epoch 20/200
# 334/334 [==============================] - 2s 5ms/step - loss: 9.1170e-04 - mae: 0.0219 - val_loss: 0.0013 - val_mae: 0.0300
# Epoch 21/200
# 334/334 [==============================] - 2s 5ms/step - loss: 8.5417e-04 - mae: 0.0215 - val_loss: 0.0021 - val_mae: 0.0401
# Epoch 22/200
# 334/334 [==============================] - 2s 5ms/step - loss: 8.6504e-04 - mae: 0.0213 - val_loss: 0.0011 - val_mae: 0.0262
# Epoch 23/200
# 334/334 [==============================] - 2s 5ms/step - loss: 8.0125e-04 - mae: 0.0207 - val_loss: 0.0017 - val_mae: 0.0346
# Epoch 24/200
# 334/334 [==============================] - 2s 5ms/step - loss: 6.7187e-04 - mae: 0.0194 - val_loss: 9.9015e-04 - val_mae: 0.0254
# Epoch 25/200
# 334/334 [==============================] - 2s 5ms/step - loss: 7.2838e-04 - mae: 0.0202 - val_loss: 0.0010 - val_mae: 0.0258
# Epoch 26/200
# 334/334 [==============================] - 2s 5ms/step - loss: 7.3238e-04 - mae: 0.0198 - val_loss: 0.0021 - val_mae: 0.0400
# Epoch 27/200
# 334/334 [==============================] - 2s 5ms/step - loss: 7.1544e-04 - mae: 0.0199 - val_loss: 0.0012 - val_mae: 0.0284
# Epoch 28/200
# 334/334 [==============================] - 2s 5ms/step - loss: 6.8168e-04 - mae: 0.0193 - val_loss: 9.3151e-04 - val_mae: 0.0246
# Epoch 29/200
# 334/334 [==============================] - 2s 5ms/step - loss: 6.5181e-04 - mae: 0.0189 - val_loss: 0.0012 - val_mae: 0.0292
# Epoch 30/200
# 334/334 [==============================] - 2s 5ms/step - loss: 6.1205e-04 - mae: 0.0181 - val_loss: 7.0868e-04 - val_mae: 0.0205
# Epoch 31/200
# 334/334 [==============================] - 2s 5ms/step - loss: 5.9791e-04 - mae: 0.0184 - val_loss: 6.3366e-04 - val_mae: 0.0190
# Epoch 32/200
# 334/334 [==============================] - 2s 5ms/step - loss: 6.3312e-04 - mae: 0.0185 - val_loss: 8.6235e-04 - val_mae: 0.0233
# Epoch 33/200
# 334/334 [==============================] - 2s 5ms/step - loss: 6.0980e-04 - mae: 0.0185 - val_loss: 0.0012 - val_mae: 0.0273
# Epoch 34/200
# 334/334 [==============================] - 2s 5ms/step - loss: 5.6537e-04 - mae: 0.0177 - val_loss: 7.6166e-04 - val_mae: 0.0216
# Epoch 35/200
# 334/334 [==============================] - 2s 5ms/step - loss: 5.7710e-04 - mae: 0.0178 - val_loss: 5.8883e-04 - val_mae: 0.0181
# Epoch 36/200
# 334/334 [==============================] - 2s 5ms/step - loss: 5.5685e-04 - mae: 0.0172 - val_loss: 7.0980e-04 - val_mae: 0.0200
# Epoch 37/200
# 334/334 [==============================] - 2s 5ms/step - loss: 5.4730e-04 - mae: 0.0175 - val_loss: 6.9687e-04 - val_mae: 0.0200
# Epoch 38/200
# 334/334 [==============================] - 2s 5ms/step - loss: 5.0494e-04 - mae: 0.0165 - val_loss: 5.6751e-04 - val_mae: 0.0179
# Epoch 39/200
# 334/334 [==============================] - 2s 5ms/step - loss: 5.2058e-04 - mae: 0.0171 - val_loss: 7.3750e-04 - val_mae: 0.0212
# Epoch 40/200
# 334/334 [==============================] - 2s 5ms/step - loss: 5.0952e-04 - mae: 0.0169 - val_loss: 6.5362e-04 - val_mae: 0.0195
# Epoch 41/200
# 334/334 [==============================] - 2s 5ms/step - loss: 5.4402e-04 - mae: 0.0169 - val_loss: 0.0019 - val_mae: 0.0378
# Epoch 42/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.7505e-04 - mae: 0.0162 - val_loss: 8.8985e-04 - val_mae: 0.0242
# Epoch 43/200
# 334/334 [==============================] - 2s 5ms/step - loss: 5.0582e-04 - mae: 0.0167 - val_loss: 0.0013 - val_mae: 0.0298
# Epoch 44/200
# 334/334 [==============================] - 2s 5ms/step - loss: 5.0534e-04 - mae: 0.0167 - val_loss: 0.0011 - val_mae: 0.0277
# Epoch 45/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.7522e-04 - mae: 0.0159 - val_loss: 5.5287e-04 - val_mae: 0.0176
# Epoch 46/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.6832e-04 - mae: 0.0163 - val_loss: 5.5349e-04 - val_mae: 0.0176
# Epoch 47/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.1791e-04 - mae: 0.0152 - val_loss: 6.5116e-04 - val_mae: 0.0198
# Epoch 48/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.5053e-04 - mae: 0.0159 - val_loss: 6.8454e-04 - val_mae: 0.0203
# Epoch 49/200
# 334/334 [==============================] - 2s 5ms/step - loss: 5.0023e-04 - mae: 0.0165 - val_loss: 8.3397e-04 - val_mae: 0.0232
# Epoch 50/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.2792e-04 - mae: 0.0155 - val_loss: 5.4077e-04 - val_mae: 0.0173
# Epoch 51/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.5144e-04 - mae: 0.0158 - val_loss: 5.1502e-04 - val_mae: 0.0167
# Epoch 52/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.4373e-04 - mae: 0.0157 - val_loss: 5.5568e-04 - val_mae: 0.0177
# Epoch 53/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.9664e-04 - mae: 0.0150 - val_loss: 6.6886e-04 - val_mae: 0.0201
# Epoch 54/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.1970e-04 - mae: 0.0155 - val_loss: 7.4790e-04 - val_mae: 0.0217
# Epoch 55/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.2468e-04 - mae: 0.0152 - val_loss: 7.8256e-04 - val_mae: 0.0224
# Epoch 56/200
# 334/334 [==============================] - 1s 4ms/step - loss: 4.0423e-04 - mae: 0.0152 - val_loss: 7.4870e-04 - val_mae: 0.0217
# Epoch 57/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.5014e-04 - mae: 0.0157 - val_loss: 4.9041e-04 - val_mae: 0.0164
# Epoch 58/200
# 334/334 [==============================] - 1s 4ms/step - loss: 4.1154e-04 - mae: 0.0154 - val_loss: 5.1185e-04 - val_mae: 0.0168
# Epoch 59/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.0197e-04 - mae: 0.0150 - val_loss: 7.5531e-04 - val_mae: 0.0213
# Epoch 60/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.1302e-04 - mae: 0.0153 - val_loss: 0.0010 - val_mae: 0.0269
# Epoch 61/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.1802e-04 - mae: 0.0152 - val_loss: 0.0013 - val_mae: 0.0310
# Epoch 62/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.7362e-04 - mae: 0.0147 - val_loss: 5.0706e-04 - val_mae: 0.0169
# Epoch 63/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.0676e-04 - mae: 0.0151 - val_loss: 6.5097e-04 - val_mae: 0.0200
# Epoch 64/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.0279e-04 - mae: 0.0148 - val_loss: 7.6620e-04 - val_mae: 0.0223
# Epoch 65/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.0505e-04 - mae: 0.0151 - val_loss: 4.7902e-04 - val_mae: 0.0161
# Epoch 66/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.9155e-04 - mae: 0.0146 - val_loss: 4.8695e-04 - val_mae: 0.0165
# Epoch 67/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.6196e-04 - mae: 0.0142 - val_loss: 5.0531e-04 - val_mae: 0.0169
# Epoch 68/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.7721e-04 - mae: 0.0146 - val_loss: 4.6396e-04 - val_mae: 0.0159
# Epoch 69/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.5965e-04 - mae: 0.0143 - val_loss: 7.8838e-04 - val_mae: 0.0228
# Epoch 70/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.6961e-04 - mae: 0.0145 - val_loss: 5.1526e-04 - val_mae: 0.0167
# Epoch 71/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.6772e-04 - mae: 0.0147 - val_loss: 4.8221e-04 - val_mae: 0.0164
# Epoch 72/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.7056e-04 - mae: 0.0144 - val_loss: 5.3660e-04 - val_mae: 0.0177
# Epoch 73/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.4192e-04 - mae: 0.0141 - val_loss: 7.1689e-04 - val_mae: 0.0205
# Epoch 74/200
# 334/334 [==============================] - 2s 5ms/step - loss: 4.0787e-04 - mae: 0.0151 - val_loss: 4.5691e-04 - val_mae: 0.0159
# Epoch 75/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.3108e-04 - mae: 0.0138 - val_loss: 7.0578e-04 - val_mae: 0.0202
# Epoch 76/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.6423e-04 - mae: 0.0145 - val_loss: 8.3093e-04 - val_mae: 0.0226
# Epoch 77/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.9132e-04 - mae: 0.0146 - val_loss: 5.8492e-04 - val_mae: 0.0180
# Epoch 78/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.4330e-04 - mae: 0.0139 - val_loss: 4.5583e-04 - val_mae: 0.0155
# Epoch 79/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.6483e-04 - mae: 0.0143 - val_loss: 5.4974e-04 - val_mae: 0.0182
# Epoch 80/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.6783e-04 - mae: 0.0143 - val_loss: 6.0573e-04 - val_mae: 0.0195
# Epoch 81/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.4913e-04 - mae: 0.0141 - val_loss: 0.0012 - val_mae: 0.0296
# Epoch 82/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.6509e-04 - mae: 0.0143 - val_loss: 9.9658e-04 - val_mae: 0.0265
# Epoch 83/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.3976e-04 - mae: 0.0139 - val_loss: 4.6858e-04 - val_mae: 0.0164
# Epoch 84/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.4712e-04 - mae: 0.0142 - val_loss: 7.1832e-04 - val_mae: 0.0218
# Epoch 85/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.4407e-04 - mae: 0.0140 - val_loss: 5.2379e-04 - val_mae: 0.0178
# Epoch 86/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.1860e-04 - mae: 0.0136 - val_loss: 4.2924e-04 - val_mae: 0.0152
# Epoch 87/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.4690e-04 - mae: 0.0139 - val_loss: 6.9657e-04 - val_mae: 0.0214
# Epoch 88/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.5040e-04 - mae: 0.0141 - val_loss: 0.0012 - val_mae: 0.0302
# Epoch 89/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.3306e-04 - mae: 0.0137 - val_loss: 4.3481e-04 - val_mae: 0.0152
# Epoch 90/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2632e-04 - mae: 0.0136 - val_loss: 6.9056e-04 - val_mae: 0.0202
# Epoch 91/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.6079e-04 - mae: 0.0142 - val_loss: 5.4834e-04 - val_mae: 0.0182
# Epoch 92/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0879e-04 - mae: 0.0132 - val_loss: 0.0015 - val_mae: 0.0348
# Epoch 93/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2919e-04 - mae: 0.0138 - val_loss: 0.0011 - val_mae: 0.0274
# Epoch 94/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.4461e-04 - mae: 0.0140 - val_loss: 4.6558e-04 - val_mae: 0.0158
# Epoch 95/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.4603e-04 - mae: 0.0141 - val_loss: 7.7072e-04 - val_mae: 0.0227
# Epoch 96/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2872e-04 - mae: 0.0140 - val_loss: 4.3563e-04 - val_mae: 0.0151
# Epoch 97/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.6282e-04 - mae: 0.0143 - val_loss: 4.1666e-04 - val_mae: 0.0148
# Epoch 98/200
# 334/334 [==============================] - 1s 4ms/step - loss: 3.2958e-04 - mae: 0.0139 - val_loss: 4.5021e-04 - val_mae: 0.0154
# Epoch 99/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9332e-04 - mae: 0.0131 - val_loss: 7.4144e-04 - val_mae: 0.0223
# Epoch 100/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.4820e-04 - mae: 0.0140 - val_loss: 4.1440e-04 - val_mae: 0.0147
# Epoch 101/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.3559e-04 - mae: 0.0138 - val_loss: 4.1537e-04 - val_mae: 0.0151
# Epoch 102/200
# 334/334 [==============================] - 1s 4ms/step - loss: 3.1307e-04 - mae: 0.0133 - val_loss: 6.0713e-04 - val_mae: 0.0186
# Epoch 103/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.1756e-04 - mae: 0.0136 - val_loss: 5.2748e-04 - val_mae: 0.0180
# Epoch 104/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.1399e-04 - mae: 0.0133 - val_loss: 4.2791e-04 - val_mae: 0.0154
# Epoch 105/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2470e-04 - mae: 0.0136 - val_loss: 5.0998e-04 - val_mae: 0.0176
# Epoch 106/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.1542e-04 - mae: 0.0133 - val_loss: 4.1526e-04 - val_mae: 0.0151
# Epoch 107/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2314e-04 - mae: 0.0137 - val_loss: 4.0494e-04 - val_mae: 0.0149
# Epoch 108/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.3626e-04 - mae: 0.0138 - val_loss: 4.4866e-04 - val_mae: 0.0160
# Epoch 109/200
# 334/334 [==============================] - 1s 4ms/step - loss: 3.2670e-04 - mae: 0.0138 - val_loss: 4.4744e-04 - val_mae: 0.0155
# Epoch 110/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.4008e-04 - mae: 0.0139 - val_loss: 4.2890e-04 - val_mae: 0.0154
# Epoch 111/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.3224e-04 - mae: 0.0138 - val_loss: 6.9747e-04 - val_mae: 0.0209
# Epoch 112/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0758e-04 - mae: 0.0135 - val_loss: 5.1641e-04 - val_mae: 0.0176
# Epoch 113/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.3871e-04 - mae: 0.0138 - val_loss: 7.1528e-04 - val_mae: 0.0210
# Epoch 114/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.4712e-04 - mae: 0.0140 - val_loss: 4.0325e-04 - val_mae: 0.0145
# Epoch 115/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9902e-04 - mae: 0.0131 - val_loss: 4.0029e-04 - val_mae: 0.0148
# Epoch 116/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0474e-04 - mae: 0.0131 - val_loss: 4.4695e-04 - val_mae: 0.0161
# Epoch 117/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2008e-04 - mae: 0.0133 - val_loss: 3.9892e-04 - val_mae: 0.0148
# Epoch 118/200
# 334/334 [==============================] - 1s 4ms/step - loss: 3.4259e-04 - mae: 0.0139 - val_loss: 5.1258e-04 - val_mae: 0.0177
# Epoch 119/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.1917e-04 - mae: 0.0134 - val_loss: 4.6558e-04 - val_mae: 0.0166
# Epoch 120/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2537e-04 - mae: 0.0135 - val_loss: 3.9115e-04 - val_mae: 0.0143
# Epoch 121/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2576e-04 - mae: 0.0134 - val_loss: 5.2667e-04 - val_mae: 0.0180
# Epoch 122/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2775e-04 - mae: 0.0136 - val_loss: 3.7831e-04 - val_mae: 0.0141
# Epoch 123/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9925e-04 - mae: 0.0134 - val_loss: 3.8204e-04 - val_mae: 0.0142
# Epoch 124/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8913e-04 - mae: 0.0130 - val_loss: 3.9862e-04 - val_mae: 0.0145
# Epoch 125/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.3700e-04 - mae: 0.0139 - val_loss: 3.7376e-04 - val_mae: 0.0140
# Epoch 126/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.1653e-04 - mae: 0.0132 - val_loss: 3.7501e-04 - val_mae: 0.0140
# Epoch 127/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2325e-04 - mae: 0.0138 - val_loss: 0.0011 - val_mae: 0.0278
# Epoch 128/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.1020e-04 - mae: 0.0135 - val_loss: 4.3056e-04 - val_mae: 0.0152
# Epoch 129/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9952e-04 - mae: 0.0132 - val_loss: 4.6449e-04 - val_mae: 0.0166
# Epoch 130/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0913e-04 - mae: 0.0134 - val_loss: 6.0815e-04 - val_mae: 0.0198
# Epoch 131/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.4534e-04 - mae: 0.0138 - val_loss: 3.9499e-04 - val_mae: 0.0146
# Epoch 132/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0323e-04 - mae: 0.0131 - val_loss: 4.5971e-04 - val_mae: 0.0164
# Epoch 133/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0543e-04 - mae: 0.0132 - val_loss: 6.9569e-04 - val_mae: 0.0209
# Epoch 134/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9150e-04 - mae: 0.0130 - val_loss: 4.7345e-04 - val_mae: 0.0168
# Epoch 135/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2722e-04 - mae: 0.0136 - val_loss: 7.8022e-04 - val_mae: 0.0233
# Epoch 136/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0943e-04 - mae: 0.0132 - val_loss: 4.0353e-04 - val_mae: 0.0149
# Epoch 137/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0866e-04 - mae: 0.0131 - val_loss: 3.9438e-04 - val_mae: 0.0147
# Epoch 138/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0861e-04 - mae: 0.0132 - val_loss: 4.2454e-04 - val_mae: 0.0154
# Epoch 139/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9963e-04 - mae: 0.0132 - val_loss: 4.1243e-04 - val_mae: 0.0151
# Epoch 140/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.1757e-04 - mae: 0.0134 - val_loss: 4.8671e-04 - val_mae: 0.0170
# Epoch 141/200
# 334/334 [==============================] - 1s 4ms/step - loss: 3.1332e-04 - mae: 0.0131 - val_loss: 7.4986e-04 - val_mae: 0.0225
# Epoch 142/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0899e-04 - mae: 0.0134 - val_loss: 5.0412e-04 - val_mae: 0.0175
# Epoch 143/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.1047e-04 - mae: 0.0135 - val_loss: 3.6389e-04 - val_mae: 0.0137
# Epoch 144/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9401e-04 - mae: 0.0129 - val_loss: 5.0037e-04 - val_mae: 0.0175
# Epoch 145/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8163e-04 - mae: 0.0127 - val_loss: 6.6953e-04 - val_mae: 0.0210
# Epoch 146/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9379e-04 - mae: 0.0128 - val_loss: 0.0011 - val_mae: 0.0287
# Epoch 147/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9126e-04 - mae: 0.0130 - val_loss: 4.3437e-04 - val_mae: 0.0157
# Epoch 148/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8860e-04 - mae: 0.0129 - val_loss: 5.4589e-04 - val_mae: 0.0185
# Epoch 149/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2520e-04 - mae: 0.0135 - val_loss: 3.5731e-04 - val_mae: 0.0135
# Epoch 150/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8791e-04 - mae: 0.0129 - val_loss: 6.4789e-04 - val_mae: 0.0206
# Epoch 151/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9978e-04 - mae: 0.0130 - val_loss: 8.2529e-04 - val_mae: 0.0238
# Epoch 152/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0193e-04 - mae: 0.0130 - val_loss: 4.7040e-04 - val_mae: 0.0166
# Epoch 153/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0443e-04 - mae: 0.0132 - val_loss: 4.6450e-04 - val_mae: 0.0165
# Epoch 154/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0771e-04 - mae: 0.0134 - val_loss: 4.5403e-04 - val_mae: 0.0162
# Epoch 155/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0846e-04 - mae: 0.0132 - val_loss: 3.5131e-04 - val_mae: 0.0135
# Epoch 156/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.7118e-04 - mae: 0.0125 - val_loss: 3.6280e-04 - val_mae: 0.0138
# Epoch 157/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.7667e-04 - mae: 0.0125 - val_loss: 7.2653e-04 - val_mae: 0.0221
# Epoch 158/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8083e-04 - mae: 0.0126 - val_loss: 3.7588e-04 - val_mae: 0.0140
# Epoch 159/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9173e-04 - mae: 0.0128 - val_loss: 5.6321e-04 - val_mae: 0.0187
# Epoch 160/200
# 334/334 [==============================] - 2s 4ms/step - loss: 2.9937e-04 - mae: 0.0130 - val_loss: 0.0015 - val_mae: 0.0339
# Epoch 161/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0000e-04 - mae: 0.0130 - val_loss: 5.7342e-04 - val_mae: 0.0191
# Epoch 162/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8877e-04 - mae: 0.0129 - val_loss: 4.4348e-04 - val_mae: 0.0161
# Epoch 163/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.2388e-04 - mae: 0.0133 - val_loss: 4.4416e-04 - val_mae: 0.0162
# Epoch 164/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0942e-04 - mae: 0.0134 - val_loss: 3.5003e-04 - val_mae: 0.0134
# Epoch 165/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8034e-04 - mae: 0.0126 - val_loss: 7.8898e-04 - val_mae: 0.0236
# Epoch 166/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8729e-04 - mae: 0.0129 - val_loss: 4.2431e-04 - val_mae: 0.0156
# Epoch 167/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.1101e-04 - mae: 0.0131 - val_loss: 4.7360e-04 - val_mae: 0.0169
# Epoch 168/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8809e-04 - mae: 0.0129 - val_loss: 3.9305e-04 - val_mae: 0.0145
# Epoch 169/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.3011e-04 - mae: 0.0138 - val_loss: 4.8833e-04 - val_mae: 0.0167
# Epoch 170/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8191e-04 - mae: 0.0126 - val_loss: 3.5692e-04 - val_mae: 0.0135
# Epoch 171/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8409e-04 - mae: 0.0127 - val_loss: 6.1787e-04 - val_mae: 0.0203
# Epoch 172/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9197e-04 - mae: 0.0130 - val_loss: 3.5671e-04 - val_mae: 0.0135
# Epoch 173/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9816e-04 - mae: 0.0129 - val_loss: 4.4312e-04 - val_mae: 0.0161
# Epoch 174/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9991e-04 - mae: 0.0132 - val_loss: 5.1338e-04 - val_mae: 0.0178
# Epoch 175/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.7990e-04 - mae: 0.0126 - val_loss: 7.1328e-04 - val_mae: 0.0221
# Epoch 176/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.0036e-04 - mae: 0.0129 - val_loss: 4.0428e-04 - val_mae: 0.0149
# Epoch 177/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8504e-04 - mae: 0.0128 - val_loss: 5.0163e-04 - val_mae: 0.0173
# Epoch 178/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9643e-04 - mae: 0.0132 - val_loss: 3.9083e-04 - val_mae: 0.0146
# Epoch 179/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8799e-04 - mae: 0.0128 - val_loss: 4.4448e-04 - val_mae: 0.0161
# Epoch 180/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9735e-04 - mae: 0.0132 - val_loss: 3.7239e-04 - val_mae: 0.0143
# Epoch 181/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9360e-04 - mae: 0.0131 - val_loss: 4.7087e-04 - val_mae: 0.0168
# Epoch 182/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.7854e-04 - mae: 0.0127 - val_loss: 9.5262e-04 - val_mae: 0.0262
# Epoch 183/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8894e-04 - mae: 0.0129 - val_loss: 4.1276e-04 - val_mae: 0.0153
# Epoch 184/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8836e-04 - mae: 0.0126 - val_loss: 5.2274e-04 - val_mae: 0.0179
# Epoch 185/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9432e-04 - mae: 0.0130 - val_loss: 4.1412e-04 - val_mae: 0.0154
# Epoch 186/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.7372e-04 - mae: 0.0125 - val_loss: 0.0013 - val_mae: 0.0313
# Epoch 187/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9152e-04 - mae: 0.0129 - val_loss: 0.0011 - val_mae: 0.0293
# Epoch 188/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.6562e-04 - mae: 0.0126 - val_loss: 4.4654e-04 - val_mae: 0.0161
# Epoch 189/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9984e-04 - mae: 0.0130 - val_loss: 4.1431e-04 - val_mae: 0.0153
# Epoch 190/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.9324e-04 - mae: 0.0128 - val_loss: 8.4924e-04 - val_mae: 0.0246
# Epoch 191/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8046e-04 - mae: 0.0127 - val_loss: 4.0806e-04 - val_mae: 0.0152
# Epoch 192/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.7759e-04 - mae: 0.0126 - val_loss: 3.9493e-04 - val_mae: 0.0147
# Epoch 193/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.6610e-04 - mae: 0.0123 - val_loss: 3.5960e-04 - val_mae: 0.0137
# Epoch 194/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.7041e-04 - mae: 0.0126 - val_loss: 6.0843e-04 - val_mae: 0.0200
# Epoch 195/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.6289e-04 - mae: 0.0122 - val_loss: 0.0014 - val_mae: 0.0327
# Epoch 196/200
# 334/334 [==============================] - 2s 5ms/step - loss: 3.1004e-04 - mae: 0.0135 - val_loss: 7.4671e-04 - val_mae: 0.0227
# Epoch 197/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.7260e-04 - mae: 0.0126 - val_loss: 5.1165e-04 - val_mae: 0.0178
# Epoch 198/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8633e-04 - mae: 0.0128 - val_loss: 3.3480e-04 - val_mae: 0.0130
# Epoch 199/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.6683e-04 - mae: 0.0122 - val_loss: 4.9515e-04 - val_mae: 0.0170
# Epoch 200/200
# 334/334 [==============================] - 2s 5ms/step - loss: 2.8452e-04 - mae: 0.0129 - val_loss: 3.3283e-04 - val_mae: 0.0130

# %%
#time_step = 16 / 200epochs / 64/64 batch_size = 4

history_dict2 = history2.history
loss_values2 = history_dict2['loss']
val_loss_values2 = history_dict2['val_loss']

 
epochs = range(1, len(loss_values2) + 1)

plt.figure(figsize=(16,8))

plt.plot(epochs, loss_values2, 'bo', label='Training loss') 
plt.plot(epochs, val_loss_values2, 'b', label='Validation loss')
plt.title('Training &amp; Validation Loss', fontsize=16)
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend()

# %%
#time step = 64 et 200 epochs

# %% [markdown]
# ### Prédiction

# %%
prediction_test_scaled = model.predict(X_test)
prediction_train_scaled = model.predict(X_train)

# %%
prediction_test_scaled2 = model2.predict(X_test)
prediction_train_scaled2 = model2.predict(X_train)

# %% [markdown]
# Nous effectuons la transformation inverse du Min Max scaler du close :

# %%
prediction_test = scaler_stock_close.inverse_transform(prediction_test_scaled)
prediction_train = scaler_stock_close.inverse_transform(prediction_train_scaled)

# %%
prediction_test2 = scaler_stock_close.inverse_transform(prediction_test_scaled2)
prediction_train2 = scaler_stock_close.inverse_transform(prediction_train_scaled2)

# %%
test = scaler_stock_close.inverse_transform(Y_test)
train = scaler_stock_close.inverse_transform(Y_train)

naif_test_transform = scaler_stock_close_naif.inverse_transform(naif_test_windows)

# %% [markdown]
# ### Mesure de la performance

# %% [markdown]
# Dans ce modèle nous essayons de prédire le prix journalier de fermeture de l'action d'Apple. Nous reprenons la prédiction naïve y_naif qui consiste à prédire pour le jour j, le prix du jour j-1. Nous considérons cette prédiction comme notre baseline et nous tentons de faire mieux.

# %%
print("L'erreur moyenne (MSE) de prédiction du modèle à 200 epochs, batch_size = 16 est de : " + str(np.sqrt(mean_squared_error(test,prediction_test))) + " $ par jour ")

print("L'erreur moyenne (MSE) de prédiction du modèle à 200 epochs, batch_size = 4 est de : " + str(np.sqrt(mean_squared_error(test,prediction_test2))) + " $ par jour ")

print("L'erreur moyenne (MSE) de prédiction du modèle naif est de : " + str(np.sqrt(mean_squared_error(test,naif_test_transform))) + " $ par jour ")
# Out:
# L'erreur moyenne (MSE) de prédiction du modèle à 200 epochs, batch_size =16 est de : 0.9360897421504242 $ par jour
# L'erreur moyenne (MSE) de prédiction du modèle à 200 epochs, batch_size =4 est de : 0.8039968177041982 $ par jour
# L'erreur moyenne (MSE) de prédiction du modèle naif est de : 0.7667010058173364 $ par jour

# %% [markdown]
# Nous ne faisons donc pas mieux que le modèle naïf. Une possibilité est d'utiliser du NLP pour avoir des informations pertinentes. De plus le cours d'Apple hors coronavirus est assez continue, le modèle naïf semble être donc particulièrement proche de la réalité, comme le montre le graphique suivant.

# %% [markdown]
# ### Affichage

# %%
plt.figure(figsize=(25,15))
plt.title("Prix de fermeture d'apple et sa prediction sur le jeu de test : time_step = 16")
plt.plot(test, color = "blue", label = 'true', alpha = 0.5)
plt.plot(prediction_test, color = "orange",label = 'modele avec 200 epochs batch_size = 8', alpha =0.5) #modèle 1 
plt.plot(prediction_test2, color = "red", label = 'modele avec 200 epochs batch_size = 4', alpha =0.5) #modèle 2

plt.plot(naif_test_transform, color = "black",label = 'naif', alpha =0.7)
plt.legend()
plt.show()

# %% [markdown]
# On voit que le modèle 2 et naif sont très proches (en effet leur différence est de 0.03 dollars par jours en moyenne

# %% [markdown]
# ### Il y a en annexe dans le github d'autres méthodes plus classiques que les LSTM, comme la régression linéaire, le gradient boosting et les MLP pour prédire le prix close d'APPL.
#
# Il était prévisible que le Gradient Boosting ne soit pas du tout approprié car il est borné. En effet on le confirme sur le graph de prédiction que sur le jeu de test il ne dépasse pas la borne ax des données précédentes

# %% [markdown]
# ## Objectif 2 : Prédire le delta
#
# Contrairement à la section 1 où nous avons utilisé l'information des closes précédents pour prédire le close suivant, l'objectif initial de la section 2 était d'essayer de prédire un output sans le donner en input, pour éviter l'overfitting.
#
# Nous avons défini plus haut un dataframe df, avec la variable delta qui correspond tout simplement à la différence entre le prix du jour courrant avec le prix de la veille. Nous avons donc les mêmes inputs mais nous voulons prédire une nouvelle variable : le delta.

# %%
df.head()
# Out:
#    High_AAPL  Close_AAPL   Low_AAPL  Open_AAPL  Adj_Close_AAPL  Close_GOLD  \
# 1  14.810000   14.765715  14.617143  14.642858       12.634213   48.220001
# 2  14.948215   14.929643  14.738214  14.819643       12.774481   48.020000
# 3  15.098214   15.085714  14.972143  14.991786       12.908023   47.540001
# 4  15.276786   15.061786  15.048214  15.196428       12.887549   47.709999
# 5  15.214286   15.115714  15.053572  15.211071       12.933691   48.330002
#
#    Close_VIX  moyenne_mobile  yesterday_close_AAPL     delta
# 1  22.219999       14.727039             14.686786  0.078929
# 2  21.480000       14.797293             14.765715  0.163928
# 3  20.629999       14.873781             14.929643  0.156072
# 4  21.070000       14.914449             15.085714 -0.023929
# 5  20.690001       14.951435             15.061786  0.053928

# %%
df_output = (df['delta'])
array_output = df_output.to_numpy()
array_output.reshape(-1)
# Out:
# array([ 0.07892895,  0.16392803,  0.15607166, ..., -0.76000214,
#         0.87250137,  1.02249908])

# %%
plt.figure(figsize=(16,10))
plt.title('Deltas des prix de femeture pour Apple', fontsize=20)
plt.plot(array_output)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Delta ($)', fontsize=18)          
plt.show()

# %% [markdown]
# Distribution des Deltas

# %%
plt.figure(figsize=(16,10))
plt.title('Répartition des deltas', fontsize=20)
plt.xlabel('Delta ($)', fontsize=18)
plt.hist(array_output, bins=100)
plt.show()

# %% [markdown]
# A ce stade, il n'est pas impensable que la distribution des deltas s'approche d'une loi gaussienne

# %%
sm.qqplot( (df.delta- df.delta.mean())/df.delta.std(), line='45')
plt.gcf().set_size_inches(15, 10)
plt.title('QQplot des deltas', fontsize=20)
pylab.show()

# %% [markdown]
# Le QQ-plot donne encore une impression d'une distribution proche de la loi Normale(0,1)

# %%
df.delta.kurtosis()
# Out:
# 7.274773583618242

# %% [markdown]
# Cependant le Kurtosis est plus grand que le seuil d'acceptation qui vaut 3. Nous ne supposons donc pas que la distribution des deltas approche celle d'une loi Normale centrée et réduite.

# %% [markdown]
# L'hypothèse de Normalité des deltas n'étant pas retenue, nous ne standardisons pas les données en les centrant puis réduisant mais nous les normalisons avec la méthode Min Max.

# %%
data_delta = df.filter(['Close_AAPL'])
dataset_delta = data_delta.values
scaler_delta = MinMaxScaler(feature_range=(0,1))
normalized_col_delta = scaler_delta.fit_transform(dataset_delta)

# %%
normalized_col_delta.shape
# Out:
# (1930, 1)

# %%
def split_data_delta(array_input, array_output,cprop_train_size, nb_columns):
    """
    Retourne : 
      Split le jeu de données en train, test à la fois pour les input, pour l'output. L'ordre est conservé. 
    
    Parametres d'entrées :
      array_input : np.array  -> jeu de données d'input
      array_output : np.array -> jeu de données d'output
      prop_train_size : float -> proportion du jeu d'entrainement
      nb_columns : int        -> nombre de features 
    
    """

    n = len(array_output)
    training_size = int(n*prop_train_size)
    test_size = n- training_size
    
    array_split_train_input = array_input[:training_size].reshape(-1,nb_columns)
    array_split_test_input = array_input[training_size:].reshape(-1,nb_columns)
    
    array_split_train_output = array_output[:training_size].reshape(-1,1)
    array_split_test_output = array_output[training_size:].reshape(-1,1)

    
    return array_split_train_input , array_split_test_input, array_split_train_output, array_split_test_output

def create_windows_data_XandY_delta(array_split_input, array_split_output, time_step ):
    """
    Retourne : Jeux de données train,test et naif avec des fenetres flissantes de taille time_step
      
    
    Parametres d'entrées :
      array_split_input : np.array          -> jeu de donnée d'input, idéalement un des deux sorti par la fonction split_data
      array_split_output : np.array         -> jeu de donnée d'output, idéalement celui sorti par la fonction split_data
      time_step : int                       -> nombre de jour dans la fenetre glissante

    """
    dataX = []
    dataY = []
    
    for i in range(len(array_split_output)- time_step - 1) : 
        set_value = array_split_input[i : (i+time_step) ,:]
        dataX.append(set_value)
        dataY.append(array_split_output[i + time_step])
        
    return np.array(dataX), np.array(dataY)

# %%
train_data_input_delta, test_data_input_delta ,train_data_output_delta, test_data_output_delta = split_data_delta(scaled_data, normalized_col_delta, prop_train_size, nb_columns)
X_train_delta, Y_train_delta= create_windows_data_XandY_delta(train_data_input_delta, train_data_output_delta, time_step)
X_test_delta, Y_test_delta = create_windows_data_XandY_delta(test_data_input_delta, test_data_output_delta, time_step)

# %% [markdown]
# ### Modèle de prédiction du delta

# %%
model_delta = Sequential()


model_delta.add(LSTM(64, return_sequences=False,input_shape=(time_step,nb_columns)))
model_delta.add(Dropout(0.2))
model_delta.add(Dense(64, activation = "relu"))
model_delta.add(Dropout(0.2))
model_delta.add(Dense(1, activation = "linear"))

adam_delta = keras.optimizers.Adam(lr=1e-4, beta_1=0.9, beta_2 = 0.999, epsilon =1e-8)
model_delta.compile(optimizer=adam_delta, loss='mean_squared_error', metrics = ["mae"])

model_delta.summary()

model_delta.fit(X_train_delta, Y_train_delta, validation_data = (X_test_delta, Y_test_delta),  verbose=1)
history_delta = model_delta.fit(X_train_delta, Y_train_delta, validation_data=(X_test_delta, Y_test_delta),  epochs = 200, batch_size=8)
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_19 (LSTM)               (None, 64)                18688
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 22,913
# Trainable params: 22,913
# Non-trainable params: 0
# _________________________________________________________________
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0237 - mae: 0.1173 - val_loss: 0.0585 - val_mae: 0.2306
# Epoch 1/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0046 - mae: 0.0514 - val_loss: 0.0059 - val_mae: 0.0657
# Epoch 2/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0032 - mae: 0.0428 - val_loss: 0.0063 - val_mae: 0.0699
# Epoch 3/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0027 - mae: 0.0391 - val_loss: 0.0064 - val_mae: 0.0711
# Epoch 4/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0023 - mae: 0.0354 - val_loss: 0.0055 - val_mae: 0.0659
# Epoch 5/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0020 - mae: 0.0339 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 6/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0018 - mae: 0.0320 - val_loss: 0.0012 - val_mae: 0.0278
# Epoch 7/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0016 - mae: 0.0299 - val_loss: 0.0023 - val_mae: 0.0400
# Epoch 8/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0015 - mae: 0.0293 - val_loss: 0.0043 - val_mae: 0.0582
# Epoch 9/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0014 - mae: 0.0285 - val_loss: 0.0019 - val_mae: 0.0357
# Epoch 10/200
# 167/167 [==============================] - 1s 6ms/step - loss: 0.0014 - mae: 0.0282 - val_loss: 0.0012 - val_mae: 0.0276
# Epoch 11/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0012 - mae: 0.0266 - val_loss: 0.0022 - val_mae: 0.0391
# Epoch 12/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0012 - mae: 0.0262 - val_loss: 0.0016 - val_mae: 0.0328
# Epoch 13/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0256 - val_loss: 0.0020 - val_mae: 0.0374
# Epoch 14/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0012 - mae: 0.0253 - val_loss: 0.0017 - val_mae: 0.0338
# Epoch 15/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0012 - mae: 0.0256 - val_loss: 0.0037 - val_mae: 0.0534
# Epoch 16/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 0.0030 - val_mae: 0.0472
# Epoch 17/200
# 167/167 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0250 - val_loss: 0.0063 - val_mae: 0.0725
# Epoch 18/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0238 - val_loss: 0.0044 - val_mae: 0.0590
# Epoch 19/200
# 167/167 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0235 - val_loss: 0.0041 - val_mae: 0.0562
# Epoch 20/200
# 167/167 [==============================] - 1s 6ms/step - loss: 9.1304e-04 - mae: 0.0228 - val_loss: 0.0038 - val_mae: 0.0543
# Epoch 21/200
# 167/167 [==============================] - 1s 6ms/step - loss: 9.4298e-04 - mae: 0.0225 - val_loss: 0.0032 - val_mae: 0.0493
# Epoch 22/200
# 167/167 [==============================] - 1s 6ms/step - loss: 9.3150e-04 - mae: 0.0225 - val_loss: 0.0033 - val_mae: 0.0496
# Epoch 23/200
# 167/167 [==============================] - 1s 6ms/step - loss: 9.0681e-04 - mae: 0.0222 - val_loss: 0.0027 - val_mae: 0.0439
# Epoch 24/200
# 167/167 [==============================] - 1s 6ms/step - loss: 8.6396e-04 - mae: 0.0219 - val_loss: 0.0023 - val_mae: 0.0405
# Epoch 25/200
# 167/167 [==============================] - 1s 5ms/step - loss: 8.8083e-04 - mae: 0.0220 - val_loss: 0.0062 - val_mae: 0.0727
# Epoch 26/200
# 167/167 [==============================] - 1s 6ms/step - loss: 8.0663e-04 - mae: 0.0214 - val_loss: 0.0052 - val_mae: 0.0661
# Epoch 27/200
# 167/167 [==============================] - 1s 6ms/step - loss: 7.9345e-04 - mae: 0.0213 - val_loss: 0.0043 - val_mae: 0.0589
# Epoch 28/200
# 167/167 [==============================] - 1s 6ms/step - loss: 7.6159e-04 - mae: 0.0205 - val_loss: 0.0031 - val_mae: 0.0488
# Epoch 29/200
# 167/167 [==============================] - 1s 6ms/step - loss: 7.4697e-04 - mae: 0.0203 - val_loss: 0.0055 - val_mae: 0.0679
# Epoch 30/200
# 167/167 [==============================] - 1s 6ms/step - loss: 7.1729e-04 - mae: 0.0202 - val_loss: 0.0026 - val_mae: 0.0440
# Epoch 31/200
# 167/167 [==============================] - 1s 5ms/step - loss: 7.3582e-04 - mae: 0.0201 - val_loss: 0.0022 - val_mae: 0.0396
# Epoch 32/200
# 167/167 [==============================] - 1s 5ms/step - loss: 7.1486e-04 - mae: 0.0201 - val_loss: 0.0044 - val_mae: 0.0595
# Epoch 33/200
# 167/167 [==============================] - 1s 5ms/step - loss: 7.3159e-04 - mae: 0.0201 - val_loss: 0.0014 - val_mae: 0.0307
# Epoch 34/200
# 167/167 [==============================] - 1s 5ms/step - loss: 7.1868e-04 - mae: 0.0203 - val_loss: 0.0049 - val_mae: 0.0633
# Epoch 35/200
# 167/167 [==============================] - 1s 5ms/step - loss: 6.7418e-04 - mae: 0.0195 - val_loss: 0.0039 - val_mae: 0.0558
# Epoch 36/200
# 167/167 [==============================] - 1s 5ms/step - loss: 6.7917e-04 - mae: 0.0193 - val_loss: 0.0026 - val_mae: 0.0447
# Epoch 37/200
# 167/167 [==============================] - 1s 5ms/step - loss: 7.0336e-04 - mae: 0.0199 - val_loss: 0.0034 - val_mae: 0.0522
# Epoch 38/200
# 167/167 [==============================] - 1s 5ms/step - loss: 6.7006e-04 - mae: 0.0191 - val_loss: 0.0046 - val_mae: 0.0619
# Epoch 39/200
# 167/167 [==============================] - 1s 5ms/step - loss: 6.1410e-04 - mae: 0.0183 - val_loss: 0.0016 - val_mae: 0.0328
# Epoch 40/200
# 167/167 [==============================] - 1s 6ms/step - loss: 6.1151e-04 - mae: 0.0180 - val_loss: 0.0035 - val_mae: 0.0528
# Epoch 41/200
# 167/167 [==============================] - 1s 6ms/step - loss: 6.2361e-04 - mae: 0.0185 - val_loss: 0.0043 - val_mae: 0.0596
# Epoch 42/200
# 167/167 [==============================] - 1s 5ms/step - loss: 5.7948e-04 - mae: 0.0183 - val_loss: 0.0038 - val_mae: 0.0554
# Epoch 43/200
# 167/167 [==============================] - 1s 5ms/step - loss: 6.1268e-04 - mae: 0.0185 - val_loss: 0.0026 - val_mae: 0.0447
# Epoch 44/200
# 167/167 [==============================] - 1s 5ms/step - loss: 6.0813e-04 - mae: 0.0183 - val_loss: 0.0019 - val_mae: 0.0363
# Epoch 45/200
# 167/167 [==============================] - 1s 5ms/step - loss: 6.0603e-04 - mae: 0.0181 - val_loss: 0.0032 - val_mae: 0.0503
# Epoch 46/200
# 167/167 [==============================] - 1s 5ms/step - loss: 5.5706e-04 - mae: 0.0177 - val_loss: 0.0026 - val_mae: 0.0445
# Epoch 47/200
# 167/167 [==============================] - 1s 5ms/step - loss: 6.2190e-04 - mae: 0.0186 - val_loss: 0.0025 - val_mae: 0.0436
# Epoch 48/200
# 167/167 [==============================] - 1s 5ms/step - loss: 5.7536e-04 - mae: 0.0179 - val_loss: 0.0026 - val_mae: 0.0442
# Epoch 49/200
# 167/167 [==============================] - 1s 5ms/step - loss: 6.0885e-04 - mae: 0.0185 - val_loss: 0.0041 - val_mae: 0.0577
# Epoch 50/200
# 167/167 [==============================] - 1s 5ms/step - loss: 5.9902e-04 - mae: 0.0178 - val_loss: 0.0019 - val_mae: 0.0373
# Epoch 51/200
# 167/167 [==============================] - 1s 5ms/step - loss: 5.2432e-04 - mae: 0.0172 - val_loss: 0.0018 - val_mae: 0.0356
# Epoch 52/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.9893e-04 - mae: 0.0170 - val_loss: 0.0030 - val_mae: 0.0488
# Epoch 53/200
# 167/167 [==============================] - 1s 5ms/step - loss: 5.2249e-04 - mae: 0.0170 - val_loss: 0.0049 - val_mae: 0.0649
# Epoch 54/200
# 167/167 [==============================] - 1s 5ms/step - loss: 5.5452e-04 - mae: 0.0174 - val_loss: 0.0028 - val_mae: 0.0464
# Epoch 55/200
# 167/167 [==============================] - 1s 5ms/step - loss: 5.1548e-04 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0277
# Epoch 56/200
# 167/167 [==============================] - 1s 5ms/step - loss: 5.2474e-04 - mae: 0.0170 - val_loss: 0.0012 - val_mae: 0.0279
# Epoch 57/200
# 167/167 [==============================] - 1s 5ms/step - loss: 5.0623e-04 - mae: 0.0165 - val_loss: 0.0019 - val_mae: 0.0379
# Epoch 58/200
# 167/167 [==============================] - 1s 5ms/step - loss: 5.0448e-04 - mae: 0.0165 - val_loss: 0.0029 - val_mae: 0.0480
# Epoch 59/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.9711e-04 - mae: 0.0169 - val_loss: 8.8082e-04 - val_mae: 0.0233
# Epoch 60/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.9322e-04 - mae: 0.0168 - val_loss: 8.5356e-04 - val_mae: 0.0226
# Epoch 61/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.9213e-04 - mae: 0.0164 - val_loss: 0.0016 - val_mae: 0.0344
# Epoch 62/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.6129e-04 - mae: 0.0160 - val_loss: 0.0016 - val_mae: 0.0344
# Epoch 63/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.7647e-04 - mae: 0.0165 - val_loss: 0.0014 - val_mae: 0.0318
# Epoch 64/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.7689e-04 - mae: 0.0164 - val_loss: 0.0038 - val_mae: 0.0563
# Epoch 65/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.5401e-04 - mae: 0.0162 - val_loss: 0.0022 - val_mae: 0.0410
# Epoch 66/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.6024e-04 - mae: 0.0160 - val_loss: 0.0026 - val_mae: 0.0446
# Epoch 67/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.8889e-04 - mae: 0.0163 - val_loss: 7.0869e-04 - val_mae: 0.0200
# Epoch 68/200
# 167/167 [==============================] - 1s 6ms/step - loss: 4.5710e-04 - mae: 0.0163 - val_loss: 0.0025 - val_mae: 0.0436
# Epoch 69/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.6862e-04 - mae: 0.0162 - val_loss: 9.8726e-04 - val_mae: 0.0249
# Epoch 70/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.3592e-04 - mae: 0.0159 - val_loss: 9.3231e-04 - val_mae: 0.0242
# Epoch 71/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.4500e-04 - mae: 0.0158 - val_loss: 0.0026 - val_mae: 0.0449
# Epoch 72/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.4950e-04 - mae: 0.0160 - val_loss: 0.0018 - val_mae: 0.0363
# Epoch 73/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.3825e-04 - mae: 0.0158 - val_loss: 0.0012 - val_mae: 0.0292
# Epoch 74/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.3274e-04 - mae: 0.0155 - val_loss: 0.0023 - val_mae: 0.0426
# Epoch 75/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.3734e-04 - mae: 0.0158 - val_loss: 0.0012 - val_mae: 0.0280
# Epoch 76/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.5850e-04 - mae: 0.0160 - val_loss: 0.0013 - val_mae: 0.0302
# Epoch 77/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.0588e-04 - mae: 0.0155 - val_loss: 0.0031 - val_mae: 0.0502
# Epoch 78/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.2823e-04 - mae: 0.0157 - val_loss: 0.0011 - val_mae: 0.0270
# Epoch 79/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.1619e-04 - mae: 0.0151 - val_loss: 0.0016 - val_mae: 0.0343
# Epoch 80/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.6963e-04 - mae: 0.0163 - val_loss: 0.0011 - val_mae: 0.0276
# Epoch 81/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.8793e-04 - mae: 0.0150 - val_loss: 0.0013 - val_mae: 0.0295
# Epoch 82/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.4879e-04 - mae: 0.0160 - val_loss: 5.4680e-04 - val_mae: 0.0181
# Epoch 83/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.3296e-04 - mae: 0.0154 - val_loss: 0.0014 - val_mae: 0.0317
# Epoch 84/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.4598e-04 - mae: 0.0156 - val_loss: 8.4343e-04 - val_mae: 0.0227
# Epoch 85/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.3258e-04 - mae: 0.0154 - val_loss: 7.1432e-04 - val_mae: 0.0204
# Epoch 86/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.2443e-04 - mae: 0.0154 - val_loss: 0.0013 - val_mae: 0.0296
# Epoch 87/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.0083e-04 - mae: 0.0151 - val_loss: 0.0017 - val_mae: 0.0360
# Epoch 88/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.7673e-04 - mae: 0.0147 - val_loss: 0.0017 - val_mae: 0.0357
# Epoch 89/200
# 167/167 [==============================] - 1s 6ms/step - loss: 3.9515e-04 - mae: 0.0152 - val_loss: 8.0921e-04 - val_mae: 0.0223
# Epoch 90/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.0828e-04 - mae: 0.0150 - val_loss: 9.9990e-04 - val_mae: 0.0258
# Epoch 91/200
# 167/167 [==============================] - 1s 6ms/step - loss: 4.3080e-04 - mae: 0.0156 - val_loss: 6.5935e-04 - val_mae: 0.0207
# Epoch 92/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.8943e-04 - mae: 0.0149 - val_loss: 5.8605e-04 - val_mae: 0.0181
# Epoch 93/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.8886e-04 - mae: 0.0146 - val_loss: 0.0012 - val_mae: 0.0295
# Epoch 94/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.0192e-04 - mae: 0.0151 - val_loss: 0.0025 - val_mae: 0.0446
# Epoch 95/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.9222e-04 - mae: 0.0150 - val_loss: 0.0016 - val_mae: 0.0341
# Epoch 96/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.7046e-04 - mae: 0.0143 - val_loss: 4.6020e-04 - val_mae: 0.0159
# Epoch 97/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.7274e-04 - mae: 0.0147 - val_loss: 0.0017 - val_mae: 0.0362
# Epoch 98/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.0348e-04 - mae: 0.0150 - val_loss: 0.0010 - val_mae: 0.0261
# Epoch 99/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.0945e-04 - mae: 0.0150 - val_loss: 7.8834e-04 - val_mae: 0.0222
# Epoch 100/200
# 167/167 [==============================] - 1s 6ms/step - loss: 3.6305e-04 - mae: 0.0143 - val_loss: 7.1912e-04 - val_mae: 0.0211
# Epoch 101/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.6502e-04 - mae: 0.0144 - val_loss: 8.9645e-04 - val_mae: 0.0244
# Epoch 102/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.5698e-04 - mae: 0.0144 - val_loss: 0.0017 - val_mae: 0.0360
# Epoch 103/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.9378e-04 - mae: 0.0148 - val_loss: 0.0013 - val_mae: 0.0298
# Epoch 104/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.8231e-04 - mae: 0.0148 - val_loss: 0.0026 - val_mae: 0.0458
# Epoch 105/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.7838e-04 - mae: 0.0150 - val_loss: 9.5343e-04 - val_mae: 0.0249
# Epoch 106/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.8551e-04 - mae: 0.0148 - val_loss: 0.0011 - val_mae: 0.0269
# Epoch 107/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.8204e-04 - mae: 0.0147 - val_loss: 5.1943e-04 - val_mae: 0.0168
# Epoch 108/200
# 167/167 [==============================] - 1s 6ms/step - loss: 3.7056e-04 - mae: 0.0147 - val_loss: 7.9871e-04 - val_mae: 0.0227
# Epoch 109/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.2686e-04 - mae: 0.0139 - val_loss: 4.7234e-04 - val_mae: 0.0160
# Epoch 110/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4892e-04 - mae: 0.0143 - val_loss: 6.4797e-04 - val_mae: 0.0195
# Epoch 111/200
# 167/167 [==============================] - 1s 6ms/step - loss: 3.7644e-04 - mae: 0.0145 - val_loss: 5.1985e-04 - val_mae: 0.0172
# Epoch 112/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.6117e-04 - mae: 0.0143 - val_loss: 0.0011 - val_mae: 0.0269
# Epoch 113/200
# 167/167 [==============================] - 1s 5ms/step - loss: 4.0220e-04 - mae: 0.0149 - val_loss: 6.5144e-04 - val_mae: 0.0199
# Epoch 114/200
# 167/167 [==============================] - 1s 6ms/step - loss: 3.6840e-04 - mae: 0.0143 - val_loss: 0.0020 - val_mae: 0.0397
# Epoch 115/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4396e-04 - mae: 0.0139 - val_loss: 9.9916e-04 - val_mae: 0.0260
# Epoch 116/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.9546e-04 - mae: 0.0149 - val_loss: 0.0012 - val_mae: 0.0291
# Epoch 117/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0669e-04 - mae: 0.0133 - val_loss: 0.0012 - val_mae: 0.0287
# Epoch 118/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.6078e-04 - mae: 0.0143 - val_loss: 8.8729e-04 - val_mae: 0.0241
# Epoch 119/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4882e-04 - mae: 0.0142 - val_loss: 8.8045e-04 - val_mae: 0.0242
# Epoch 120/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.6701e-04 - mae: 0.0141 - val_loss: 7.2272e-04 - val_mae: 0.0213
# Epoch 121/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4291e-04 - mae: 0.0141 - val_loss: 4.8189e-04 - val_mae: 0.0163
# Epoch 122/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.7036e-04 - mae: 0.0146 - val_loss: 0.0012 - val_mae: 0.0287
# Epoch 123/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4035e-04 - mae: 0.0142 - val_loss: 5.6540e-04 - val_mae: 0.0180
# Epoch 124/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3049e-04 - mae: 0.0135 - val_loss: 0.0028 - val_mae: 0.0485
# Epoch 125/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.6471e-04 - mae: 0.0145 - val_loss: 6.7750e-04 - val_mae: 0.0201
# Epoch 126/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4677e-04 - mae: 0.0141 - val_loss: 6.8459e-04 - val_mae: 0.0206
# Epoch 127/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.5001e-04 - mae: 0.0140 - val_loss: 8.4620e-04 - val_mae: 0.0236
# Epoch 128/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3628e-04 - mae: 0.0138 - val_loss: 0.0013 - val_mae: 0.0307
# Epoch 129/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.1851e-04 - mae: 0.0137 - val_loss: 7.0494e-04 - val_mae: 0.0210
# Epoch 130/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4760e-04 - mae: 0.0137 - val_loss: 9.3278e-04 - val_mae: 0.0248
# Epoch 131/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4253e-04 - mae: 0.0138 - val_loss: 5.4500e-04 - val_mae: 0.0177
# Epoch 132/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4388e-04 - mae: 0.0141 - val_loss: 8.2490e-04 - val_mae: 0.0233
# Epoch 133/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3797e-04 - mae: 0.0138 - val_loss: 7.4919e-04 - val_mae: 0.0219
# Epoch 134/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4029e-04 - mae: 0.0137 - val_loss: 4.5160e-04 - val_mae: 0.0158
# Epoch 135/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3092e-04 - mae: 0.0137 - val_loss: 4.5918e-04 - val_mae: 0.0159
# Epoch 136/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.1790e-04 - mae: 0.0135 - val_loss: 0.0013 - val_mae: 0.0305
# Epoch 137/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3132e-04 - mae: 0.0138 - val_loss: 7.3939e-04 - val_mae: 0.0218
# Epoch 138/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4211e-04 - mae: 0.0139 - val_loss: 8.6232e-04 - val_mae: 0.0237
# Epoch 139/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.2753e-04 - mae: 0.0137 - val_loss: 9.1050e-04 - val_mae: 0.0247
# Epoch 140/200
# 167/167 [==============================] - 1s 6ms/step - loss: 3.2589e-04 - mae: 0.0135 - val_loss: 8.4088e-04 - val_mae: 0.0234
# Epoch 141/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4579e-04 - mae: 0.0141 - val_loss: 9.3329e-04 - val_mae: 0.0252
# Epoch 142/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.2606e-04 - mae: 0.0138 - val_loss: 5.3787e-04 - val_mae: 0.0177
# Epoch 143/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3958e-04 - mae: 0.0141 - val_loss: 7.0825e-04 - val_mae: 0.0211
# Epoch 144/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3860e-04 - mae: 0.0138 - val_loss: 5.9342e-04 - val_mae: 0.0188
# Epoch 145/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.5553e-04 - mae: 0.0143 - val_loss: 4.3253e-04 - val_mae: 0.0161
# Epoch 146/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.2938e-04 - mae: 0.0137 - val_loss: 5.3097e-04 - val_mae: 0.0174
# Epoch 147/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.4414e-04 - mae: 0.0138 - val_loss: 9.0227e-04 - val_mae: 0.0244
# Epoch 148/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.1873e-04 - mae: 0.0135 - val_loss: 0.0011 - val_mae: 0.0279
# Epoch 149/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3165e-04 - mae: 0.0137 - val_loss: 4.7727e-04 - val_mae: 0.0161
# Epoch 150/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0609e-04 - mae: 0.0133 - val_loss: 4.8670e-04 - val_mae: 0.0164
# Epoch 151/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.2736e-04 - mae: 0.0136 - val_loss: 8.1502e-04 - val_mae: 0.0228
# Epoch 152/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.2454e-04 - mae: 0.0137 - val_loss: 7.8636e-04 - val_mae: 0.0222
# Epoch 153/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0893e-04 - mae: 0.0131 - val_loss: 3.9340e-04 - val_mae: 0.0146
# Epoch 154/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3999e-04 - mae: 0.0137 - val_loss: 3.9702e-04 - val_mae: 0.0150
# Epoch 155/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.2725e-04 - mae: 0.0137 - val_loss: 0.0012 - val_mae: 0.0290
# Epoch 156/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3223e-04 - mae: 0.0137 - val_loss: 0.0015 - val_mae: 0.0333
# Epoch 157/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.9950e-04 - mae: 0.0132 - val_loss: 5.6832e-04 - val_mae: 0.0181
# Epoch 158/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3816e-04 - mae: 0.0138 - val_loss: 7.0262e-04 - val_mae: 0.0209
# Epoch 159/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.1801e-04 - mae: 0.0136 - val_loss: 0.0014 - val_mae: 0.0321
# Epoch 160/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.1827e-04 - mae: 0.0134 - val_loss: 6.7182e-04 - val_mae: 0.0204
# Epoch 161/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0477e-04 - mae: 0.0132 - val_loss: 0.0010 - val_mae: 0.0264
# Epoch 162/200
# 167/167 [==============================] - 1s 6ms/step - loss: 3.0141e-04 - mae: 0.0130 - val_loss: 0.0010 - val_mae: 0.0260
# Epoch 163/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.9545e-04 - mae: 0.0130 - val_loss: 0.0010 - val_mae: 0.0258
# Epoch 164/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.1816e-04 - mae: 0.0134 - val_loss: 7.0880e-04 - val_mae: 0.0209
# Epoch 165/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.2538e-04 - mae: 0.0137 - val_loss: 5.1146e-04 - val_mae: 0.0169
# Epoch 166/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0861e-04 - mae: 0.0131 - val_loss: 0.0011 - val_mae: 0.0271
# Epoch 167/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.1545e-04 - mae: 0.0135 - val_loss: 0.0010 - val_mae: 0.0262
# Epoch 168/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3233e-04 - mae: 0.0136 - val_loss: 0.0016 - val_mae: 0.0345
# Epoch 169/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.9436e-04 - mae: 0.0130 - val_loss: 6.1571e-04 - val_mae: 0.0190
# Epoch 170/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3419e-04 - mae: 0.0138 - val_loss: 6.4233e-04 - val_mae: 0.0196
# Epoch 171/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.9251e-04 - mae: 0.0128 - val_loss: 0.0012 - val_mae: 0.0295
# Epoch 172/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.3161e-04 - mae: 0.0140 - val_loss: 0.0012 - val_mae: 0.0288
# Epoch 173/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.9602e-04 - mae: 0.0131 - val_loss: 0.0010 - val_mae: 0.0264
# Epoch 174/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.9033e-04 - mae: 0.0129 - val_loss: 5.1868e-04 - val_mae: 0.0170
# Epoch 175/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0856e-04 - mae: 0.0131 - val_loss: 0.0015 - val_mae: 0.0324
# Epoch 176/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0571e-04 - mae: 0.0134 - val_loss: 6.3811e-04 - val_mae: 0.0192
# Epoch 177/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.2782e-04 - mae: 0.0134 - val_loss: 4.8735e-04 - val_mae: 0.0164
# Epoch 178/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.1617e-04 - mae: 0.0136 - val_loss: 5.4769e-04 - val_mae: 0.0178
# Epoch 179/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.8187e-04 - mae: 0.0124 - val_loss: 0.0013 - val_mae: 0.0301
# Epoch 180/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0890e-04 - mae: 0.0132 - val_loss: 7.0930e-04 - val_mae: 0.0208
# Epoch 181/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.1703e-04 - mae: 0.0134 - val_loss: 8.5793e-04 - val_mae: 0.0232
# Epoch 182/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.7426e-04 - mae: 0.0127 - val_loss: 0.0016 - val_mae: 0.0344
# Epoch 183/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.9021e-04 - mae: 0.0129 - val_loss: 0.0011 - val_mae: 0.0275
# Epoch 184/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0560e-04 - mae: 0.0133 - val_loss: 6.4839e-04 - val_mae: 0.0197
# Epoch 185/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0227e-04 - mae: 0.0133 - val_loss: 4.9068e-04 - val_mae: 0.0165
# Epoch 186/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0168e-04 - mae: 0.0131 - val_loss: 0.0011 - val_mae: 0.0270
# Epoch 187/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.1429e-04 - mae: 0.0136 - val_loss: 6.4429e-04 - val_mae: 0.0196
# Epoch 188/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.8964e-04 - mae: 0.0129 - val_loss: 5.7925e-04 - val_mae: 0.0185
# Epoch 189/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.9406e-04 - mae: 0.0132 - val_loss: 7.4780e-04 - val_mae: 0.0216
# Epoch 190/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0710e-04 - mae: 0.0133 - val_loss: 6.5857e-04 - val_mae: 0.0199
# Epoch 191/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.9766e-04 - mae: 0.0131 - val_loss: 5.0320e-04 - val_mae: 0.0168
# Epoch 192/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0533e-04 - mae: 0.0133 - val_loss: 7.8624e-04 - val_mae: 0.0221
# Epoch 193/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.1043e-04 - mae: 0.0132 - val_loss: 0.0016 - val_mae: 0.0334
# Epoch 194/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0905e-04 - mae: 0.0135 - val_loss: 0.0011 - val_mae: 0.0278
# Epoch 195/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.9154e-04 - mae: 0.0131 - val_loss: 6.1531e-04 - val_mae: 0.0190
# Epoch 196/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.1928e-04 - mae: 0.0134 - val_loss: 5.5241e-04 - val_mae: 0.0178
# Epoch 197/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0160e-04 - mae: 0.0132 - val_loss: 4.7372e-04 - val_mae: 0.0161
# Epoch 198/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0448e-04 - mae: 0.0130 - val_loss: 7.2736e-04 - val_mae: 0.0209
# Epoch 199/200
# 167/167 [==============================] - 1s 5ms/step - loss: 3.0558e-04 - mae: 0.0134 - val_loss: 7.7438e-04 - val_mae: 0.0217
# Epoch 200/200
# 167/167 [==============================] - 1s 5ms/step - loss: 2.9101e-04 - mae: 0.0128 - val_loss: 0.0011 - val_mae: 0.0273

# %%
history_dict_delta = history_delta.history
loss_values_delta = history_dict_delta['loss']
val_loss_values_delta = history_dict_delta['val_loss']
mae_delta = history_dict_delta['mae']
val_mae_delta = history_dict_delta['val_mae']
 
epochs = range(1, len(loss_values_delta) + 1)
fig_delta, ax_delta = plt.subplots(1, 2, figsize=(14, 6))

ax_delta[0].plot(epochs, mae_delta, 'bo', label='Training mae')
ax_delta[0].plot(epochs, val_mae_delta, 'b', label='Validation mae')
ax_delta[0].set_title('Training &amp; Validation mae', fontsize=16)
ax_delta[0].set_xlabel('Epochs', fontsize=16)
ax_delta[0].set_ylabel('mae', fontsize=16)
ax_delta[0].legend()
 
ax_delta[1].plot(epochs, loss_values_delta, 'bo', label='Training loss') 
ax_delta[1].plot(epochs, val_loss_values_delta, 'b', label='Validation loss')
ax_delta[1].set_title('Training &amp; Validation Loss', fontsize=16)
ax_delta[1].set_xlabel('Epochs', fontsize=16)
ax_delta[1].set_ylabel('Loss', fontsize=16)
ax_delta[1].legend()

# %%
train_predict_delta = model.predict(X_train_delta)
test_predict_delta = model.predict(X_test_delta)

# %%
delta_inverse = scaler_delta.inverse_transform(test_predict_delta)

# %% [markdown]
# La distribution de ce qui à été prédit sur les valeurs réelles :

# %%
plt.figure(figsize=(16,10))
plt.title('distribution de la prédiction sur les valeurs réelles')
plt.hist(Y_train_delta.reshape(-1), bins = 100, label = "true", alpha =0.3)
plt.hist(train_predict_delta.reshape(-1), bins = 100, label = "predict", alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# ### Score final delta

# %%
print("L'erreur moyenne (MSE) de prédiction du modèle à 200 epochs, batch_size = 8 est de : " + str(np.sqrt(mean_squared_error(Y_test_delta,test_predict_delta))) + " $ par jour ")
print("L'erreur moyenne (MSE) de prédiction du modèle naif (qui consite en la moyenne des delta) est de : " + str(np.sqrt(mean_squared_error(Y_test_delta,np.ones(len(Y_test_delta))*Y_train_delta.mean()))) +" $ par jour")
# Out:
# L'erreur moyenne (MSE) de prédiction du modèle à 200 epochs, batch_size = 8 est de : 0.02124096813622071 $ par jour
# L'erreur moyenne (MSE) de prédiction du modèle naif (qui consite en la moyenne des delta) est de : 0.4960670491126734 $ par jour

# %% [markdown]
# Nous faisons mieux que la moyenne, même sur cette distribution qui semble assez symétrique.

# %% [markdown]
# ## Objectif 3 : **Classifier** par rapport au delta

# %% [markdown]
# Nous avons voulu également prévoir le signe "delta", différence de prix du close Apple d'un jour à l'autre, plutôt que les deltas eux-mêmes, ce qui peut être une idée efficace pour une stratégie.
# Comme nous voulons prédire deux classes: soit une augmentation du close, soit une diminution, nous devons utiliser un algorithme de classification. Nous avons deux classes, donc notre idée est d'utiliser un support vector classifier.

# %% [markdown]
# ### Import des librairies de la section

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score

# %%
df["class"] = np.where(df["delta"]>0,1,-1)
df.head()
# Out:
#    High_AAPL  Close_AAPL   Low_AAPL  Open_AAPL  Adj_Close_AAPL  Close_GOLD  \
# 1  14.810000   14.765715  14.617143  14.642858       12.634213   48.220001
# 2  14.948215   14.929643  14.738214  14.819643       12.774481   48.020000
# 3  15.098214   15.085714  14.972143  14.991786       12.908023   47.540001
# 4  15.276786   15.061786  15.048214  15.196428       12.887549   47.709999
# 5  15.214286   15.115714  15.053572  15.211071       12.933691   48.330002
#
#    Close_VIX  moyenne_mobile  yesterday_close_AAPL     delta  class
# 1  22.219999       14.727039             14.686786  0.078929      1
# 2  21.480000       14.797293             14.765715  0.163928      1
# 3  20.629999       14.873781             14.929643  0.156072      1
# 4  21.070000       14.914449             15.085714 -0.023929     -1
# 5  20.690001       14.951435             15.061786  0.053928      1

# %%
df['class'].describe()
# Out:
# count    1930.000000
# mean        0.040415
# std         0.999442
# min        -1.000000
# 25%        -1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: class, dtype: float64

# %% [markdown]
# ### Modèle SVM

# %%
df_output = df[['class']]
y_class = df_output.to_numpy()

# %%
y_class.shape
# Out:
# (1930, 1)

# %%
X_class = df[['High_AAPL', 'Close_AAPL', 'Low_AAPL', 'Open_AAPL', 'Adj_Close_AAPL', 'Close_GOLD', 'Close_VIX', 'moyenne_mobile']].to_numpy()

# %%
X_class.shape
# Out:
# (1930, 8)

# %%
scaler = MinMaxScaler(feature_range = (0,1))
X_normalise_class = scaler.fit_transform(X_class)

# %%
training_size = int(0.7*len(y_class))
training_size
# Out:
# 1351

# %%
X_train_class, X_test_class, y_train_class, y_test_class = train_test_split(X_class,y_class,train_size=0.7)

svclassifier = svm.SVC(kernel='linear',random_state=0)
svclassifier.fit(X_train_class,y_train_class)
# Out:
# /home/berrebi/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVC(kernel='linear', random_state=0)

# %%
y_pred_class=svclassifier.predict(X_test_class)
svclassifier.score(X_test_class,y_test_class)
cm_svm=confusion_matrix(y_test_class,y_pred_class)
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# [[205  62]
#  [ 48 264]]

# %% [markdown]
# Nous obtenons donc 216 vrais positifs et 268 vrais negatifs, ce qui donne une performance de (216+268)/579=0.836

# %% [markdown]
# Cross validation : voyons si ça fonctionne si nous changons les données de test. Nous divisons le dataframe en 5 groupes, et nous prenons 4 groupes parmi les 5 pour les données de train, le groupe restant pour les données de test.

# %%
clf = svm.SVC(kernel='linear', C=1)
scores = cross_val_score(clf, X_class, y_class, cv=5)
scores
#cv=5 implique une taille de train de 80%, taille de test de 20%
#renvoie une array, score sur 5 jeux de tests, mais pas un modèle seul

#voir l'accuracy moyenne:
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# /home/berrebi/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /home/berrebi/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /home/berrebi/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /home/berrebi/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /home/berrebi/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.81 (+/- 0.07)

# %% [markdown]
# Nous pouvons calculer la sensitivity et la specificity :

# %%
total1=sum(sum(cm_svm))


accuracy1=(cm_svm[0,0]+cm_svm[1,1])/total1
print ('Accuracy : ', accuracy1)

#Plus la sensitivity est proche de 1, plus la proportion de vrais positifs est élevée, et plus la proportion de faux negatifs est faible.
sensitivity1 = cm_svm[0,0]/(cm_svm[0,0]+cm_svm[0,1])
print('Sensitivity : ', sensitivity1 )


#Plus la sensitivity est proche de 1, plus la proportion de vrais négatifs est élevée, et plus la proportion de faux positifs est faible   
specificity1 = cm_svm[1,1]/(cm_svm[1,0]+cm_svm[1,1])
print('Specificity : ', specificity1)
# Out:
# Accuracy :  0.8100172711571675
# Sensitivity :  0.7677902621722846
# Specificity :  0.8461538461538461

# %% [markdown]
# Interprétation :

# %% [markdown]
# ## Exemple d'application: élaboration d'une stratégie financière

# %% [markdown]
# Le but de nos prédictions est de pouvoir ensuite anticiper les prix du lendemain. Trouver la stratégie financière optimale peut s'avérer complexe. Néanmoins, nous proposons ici une stratégie assez simple pour montrer l'intérêt concret de nos prédictions.

# %% [markdown]
# Les prédictions utilisées ont été obtenues avec le modèle LSTM qui prédit directement le close du lendemain à partir des données antérieures sans l'open. Après apprentissage sur les données pour prédire le close, nous avons appliquer le même modèle pour prédire l'open en lui fournissant les données antérieures d'open. Comme les prix d'open et de close évoluent de façon assez similaires, utiliser le même modèle pour les deux fournit de meilleures prédictions. Les données suivantes peuvent être retrouvées en annexe et fournissent des prédictions en 2020 pour l'open et le close d'Apple.

# %%
open_reel = np.load('C:\\Users\\User\\Desktop\\Predictions\\open_reel.npy')
close_reel = np.load('C:\\Users\\User\\Desktop\\Predictions\\close_reel.npy')
open_prediction = np.load('C:\\Users\\User\\Desktop\\Predictions\\open_prediction.npy')
close_prediction = np.load('C:\\Users\\User\\Desktop\\Predictions\\close_prediction.npy')

# %% [markdown]
# L'idée de notre prédiction repose sur le calcul de la différence entre le close et l'open. Si cette différente est positive et suffisamment grande, nous achetons à l'open et vendons au close. Inversement si la différence est grande mais négative, nous vendons à découverte à l'open et achetons au close. Pour fixer un ordre de grandeur, nous calculons la moyenne et l'écart type des différences réelles entre le close et l'open pour cette année.

# %%
start = pd.to_datetime('2020-01-01')
end = pd.to_datetime('today')
df_stock = web.DataReader('AAPL', data_source='yahoo', start=start, end=end)
df = abs(df_stock['Close'] - df_stock ['Open'] )
# Out:
# count    239.000000
# mean       1.420084
# std        1.258967
# min        0.009995
# 25%        0.508747
# 50%        1.099998
# 75%        1.958748
# max        6.870003
# dtype: float64

# %%
difference = close_prediction - open_prediction

# %% [markdown]
# Si la différence entre le close et l'open prédits pour le lendemain est supérieure à 3 écarts types de la moyenne des écarts réels, nous passons une opération qui consiste à acheter 10 actions à l'open et les vendre au close (ou une vente à découverte de 10 actions à l'open et rachat au close si nos prédictions sont baissières). Notre portefeuille contient initialement 1000 dollars.

# %%
initial = 1000
portefeuille = 1000
epsilon = df.mean() + 3*df.std()
for k in range(len(difference)):
        if difference[k] > epsilon:
            portefeuille-=10*open_reel[k]
            portefeuille+=10*close_reel[k]
        if difference[k] < -epsilon:
            portefeuille+=10*open_reel[k]
            portefeuille-=10*close_reel[k]

print('portefeuille final :', float(portefeuille))
print('gain en pourcent :', float((portefeuille - initial) / initial)*100)
# Out:
# portefeuille final : 1040.0000762939455
# gain en pourcent : 4.0000076293945535

# %% [markdown]
# Ainsi, nous parvenons à réaliser un gain de 4% avec les données prédites. L'écart choisi pour décider de mener une opération est assez important. Prendre un écart moins important peut s'avérer risquer en raison de la précision de nos prédictions qui ne collent pas toujours à la réalité.
